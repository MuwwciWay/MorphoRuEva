# %%
import json
import re
import pandas as pd

def parse_json(file_path):
    # Загружаем JSON файл
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    # Будем использовать список для хранения информации
    extracted_data = []

    for item in data:
        # Проверяем заголовок задания
        if item.get("title") == "Расставьте знаки препинания.":
            # Извлекаем описание и определяем нужный знак препинания
            description = item.get("description", "")
            punctuation_sign = extract_punctuation_sign(description)
            
            # Извлекаем само задание и ответ ученика
            task_text = item.get("task", "")
            student_answer = item.get("answer", "")
            answer = item.get("input_answer", "")
            
            # Сохраняем данные в виде словаря
            extracted_data.append({
                "description": description,
                "punctuation_sign": punctuation_sign,
                "task_text": task_text,
                "student_answer": student_answer,
                "answer": answer
            })

    # Конвертируем список в DataFrame для удобства анализа
    df = pd.DataFrame(extracted_data)
    return df

def extract_punctuation_sign(description):
    """Функция для извлечения знака препинания из описания задания."""
    if "запятые" in description.lower():
        return ","
    elif "тире" in description.lower():
        return "—"
    elif "двоеточие" in description.lower():
        return ":"
    elif "точка с запятой" in description.lower():
        return ";"
    return None

# Пример вызова функции
file_path = 'dataset.json'
df = parse_json(file_path)


import re
from transformers import pipeline, AutoTokenizer
import logging




# Отключаем все логирование
logging.disable(logging.CRITICAL)


# Загрузка модели для расстановки пунктуации
pt = "RUPunct/RUPunct_big"

tk = AutoTokenizer.from_pretrained(pt, strip_accents=False, add_prefix_space=True)
classifier = pipeline("ner", model=pt, tokenizer=tk, aggregation_strategy="first")


import re

def process_token(token, label, prev_char, is_start_of_sentence):
    """Обработка токенов в зависимости от их метки без изменения регистра, с капитализацией в начале предложения."""
    new_token = token
    substitution = None

    if label == "LOWER_O":
        return token, None
    if label in ["LOWER_COMMA", "UPPER_COMMA", "UPPER_TOTAL_COMMA"]:
        if prev_char != ',':
            new_token += ","
            substitution = ","
    elif label in ["LOWER_QUESTION", "UPPER_QUESTION", "UPPER_TOTAL_QUESTION"]:
        if prev_char != '?':
            new_token += "?"
            substitution = "?"
    elif label == "LOWER_TIRE":
        new_token = " " + token + " —"
        substitution = " —"
    elif label == "UPPER_TIRE":
        new_token = " " + token.capitalize() + " —"
        substitution = " —"
    elif label == "LOWER_DVOETOCHIE":
        new_token += ":"
        substitution = ":"
    elif label == "LOWER_VOSKL":
        new_token += "!"
        substitution = "!"
    elif label == "LOWER_PERIODCOMMA":
        new_token += ";"
        substitution = ";"
    elif label == "LOWER_DEFIS":
        new_token += "-"
        substitution = "-"
    elif label == "LOWER_MNOGOTOCHIE":
        new_token += "..."
        substitution = "..."
    elif label == "LOWER_QUESTIONVOSKL":
        new_token += "?!"
        substitution = "?!"
    elif label == "UPPER_O":
        new_token = token.capitalize()
    elif label == "UPPER_TOTAL_O":
        new_token = token.upper()

    # Если это начало предложения, делаем первую букву заглавной
    if is_start_of_sentence and new_token:
        new_token = new_token.capitalize()

    return new_token, substitution

def punctuate_and_get_symbols(sentence):
    """Функция для расстановки пунктуации и генерации списка вставленных знаков для одного предложения."""
    print("Исходное предложение:", sentence)
    modified_sentence = re.sub(r'\(\d+\)', '', sentence).strip()
    print("После удаления меток:", modified_sentence)
    modified_sentence = re.sub(r'[^\w\s]', '', modified_sentence)

    preds = classifier(modified_sentence)

    output = ""
    prev_char = ""
    symbols = {}
    symbol_counter = 1  # Счетчик для нумерации вставленных знаков

    for index, item in enumerate(preds):
        is_start_of_sentence = (index == 0 or prev_char in ".!?")  # Определяем, является ли токен началом предложения
        token, substitution = process_token(item['word'].strip(), item['entity_group'], prev_char, is_start_of_sentence)

        if substitution:
            symbols[symbol_counter] = substitution
            symbol_counter += 1  # Увеличиваем счетчик только при добавлении знака

        if token and token[0] not in ",!?;:":  # Не добавляем лишние пробелы
            output += " " + token
        else:
            output += token

        prev_char = token[-1] if token else prev_char

    output = output.strip()
    print("Финальное предложение:", output)
    return output, symbols



def process_text(input_text):
    """Функция для обработки всего текста, разбивая его на предложения."""
    sentences = re.split(r'(?<=[.!?]) +', input_text)
    processed_sentences = []
    all_symbols = {}

    for i, sentence in enumerate(sentences):
        processed_sentence, symbols = punctuate_and_get_symbols(sentence)

        # Добавляем точку в конце, если она отсутствует
        if processed_sentence and processed_sentence[-1] not in ".!?":
            processed_sentence += "."
        
        processed_sentences.append(processed_sentence)

        for num, symbol in symbols.items():
            all_symbols[len(all_symbols) + 1] = symbol  # Нумерация знаков по порядку

    final_output = ' '.join(processed_sentences)
    return final_output, all_symbols

def extract_punctuation_sign(task_description):
    """Функция для извлечения знака препинания из задания."""
    if "запятые" in task_description.lower():
        return ","
    elif "тире" in task_description.lower():
        return "—"
    elif "двоеточие" in task_description.lower():
        return ":"
    elif "точка с запятой" in task_description.lower():
        return ";"
    return None

def find_punctuation(input_text, task_description):
    """Функция для нахождения позиций нужного знака."""
    required_sign = extract_punctuation_sign(task_description)
    if required_sign is None:
        return []

    processed_text, symbols = process_text(input_text)
    
    # Получаем все метки из текста, даже если они пусты
    markers = sorted(int(num) for num in re.findall(r'\((\d+)\)', input_text))
    
    # Заполняем позиции, включая "N" для пустых меток
    all_positions = {marker: symbols.get(marker, 'N') for marker in markers}

    return processed_text, all_positions

def compare_punctuation(input_text, punctuation_indices):
    """Сравнивает, какие метки были заменены на какие знаки."""
    markers = re.findall(r'\((\d+)\)', input_text)

    changes = {}
    for marker in markers:
        marker_num = int(marker)
        original_marker = f"({marker_num})"
        added_symbol = punctuation_indices.get(marker_num, "N")

        # Сопоставление замены
        changes[original_marker] = added_symbol

    return changes

def extract_labels(text):
    """Извлекает метки в формате (число) из текста."""
    labels = re.findall(r'\(\d+\)', text)
    return labels

def compare_labels(original_text, modified_text):
    """Сравнивает метки и определяет, что с ними произошло в модифицированном тексте."""
    changes = {}
    print(f"Оригинальный текст: {original_text}")
    print(f"Изменённый текст: {modified_text}")

    # Разделяем оригинальный текст на слова
    original_words = original_text.split()
    print(f"Слова в оригинальном тексте: {original_words}")

    # Проходим по словам и ищем метки
    for i in range(len(original_words)):
        word = original_words[i]
        print(f"\nОбрабатываем слово: {word} (Индекс {i})")
        
        # Если это метка
        if '(' in word and ')' in word:
            label = word  # Сохраняем метку
            print(f"Найдена метка: {label}")

            # Берем слово после метки как правую границу
            right_word = original_words[i + 1] if i < len(original_words) - 1 else ''
            print(f"Слово справа от метки: {right_word}")

            # Ищем правую границу в изменённом тексте
            right_index = modified_text.find(right_word)
            print(f"Индекс правой границы в изменённом тексте: {right_index}")

            if right_index == -1:
                changes[label] = 'Nan'  # Если правое слово не найдено
                print(f"{label}: Правое слово не найдено, устанавливаем значение 'Nan'")
                continue

            # Ищем левую границу
            left_word = original_words[i - 1] if i > 0 else ''
            print(f"Слово слева от метки: {left_word}")

            left_index = modified_text.rfind(left_word, 0, right_index)
            print(f"Индекс левой границы в изменённом тексте: {left_index}")

            if left_index == -1:
                changes[label] = 'Nan'  # Если левое слово не найдено
                print(f"{label}: Левое слово не найдено, устанавливаем значение 'Nan'")
                continue
            
            # Проверяем расстояние между границами
            while True:
                # Ищем пробелы и специальные символы между границами
                distance = right_index - (left_index + len(left_word))  # Рассчитываем расстояние
                print(f"Расстояние между границами: {distance}")

                if distance <= 3:  # Если расстояние корректное
                    # Извлекаем текст между словами
                    text_between = modified_text[left_index + len(left_word):right_index].strip()
                    print(f"Текст между границами: '{text_between}'")

                    # Проверяем наличие специальных знаков
                    if any(char in text_between for char in " ,:;-—"):
                        changes[label] = text_between
                        print(f"{label}: Найден текст со специальными символами: '{text_between}'")
                    else:
                        changes[label] = 'Nan'  # Если специальные знаки не найдены
                        print(f"{label}: Специальные символы не найдены, устанавливаем значение 'Nan'")
                    break  # Выходим из цикла после успешного извлечения текста

                # Если расстояние слишком большое, ищем новую левую границу
                left_index = modified_text.rfind(left_word, 0, left_index)  # Ищем левую границу заново
                print(f"Новый индекс левой границы: {left_index}")
                
                if left_index == -1 or left_index >= right_index:
                    changes[label] = 'Nan'  # Если не нашли соответствия
                    print(f"{label}: Левое слово не найдено или находится в некорректной позиции, устанавливаем значение 'Nan'")
                    break  # Выходим из цикла, если левое слово не найдено

                left_word = modified_text[left_index:left_index + len(original_words[i - 1])].strip()
                print(f"Новое слово для левой границы: {left_word}")

    print(f"\nИзменения: {changes}")
    return changes


def process_task_text(row):
    input_text = row['task_text']
    task_description = row['description']

    # Применяем ваш алгоритм
    processed_text, punctuation_indices = find_punctuation(input_text, task_description)

    label_changes = compare_labels(input_text, processed_text)
    
    # Возвращаем как кортеж или словарь, если нужно больше данных
    return processed_text, label_changes  # Или любой другой формат

# Обновляем DataFrame для хранения нескольких выходных данных
df[['model_answer', 'punctuation_indices']] = df.apply(process_task_text, axis=1, result_type='expand')
# Out:
# Исходное предложение: Суздальский музей деревянного зодчества (1) настоящий городок (2) построенный без единого гвоздя.
# После удаления меток: Суздальский музей деревянного зодчества  настоящий городок  построенный без единого гвоздя.
# Финальное предложение: Суздальский музей деревянного зодчества Настоящий городок, построенный без единого гвоздя
# Исходное предложение: Из дерева здесь всё (3) ложки и лавки в избе, и даже крытая лемехом церковная маковка.
# После удаления меток: Из дерева здесь всё  ложки и лавки в избе, и даже крытая лемехом церковная маковка.
# Финальное предложение: Из дерева здесь всё: ложки, и лавки в избе, и даже крытая лемехом церковная маковка
# Исходное предложение: Мельницы (4) церковь (5) дома́ (6) амбары и бани (7) всё привезено сюда из разных сёл Владимирской области и поставлено на территории несохранившегося Дмитриевского монастыря.
# После удаления меток: Мельницы  церковь  дома́  амбары и бани  всё привезено сюда из разных сёл Владимирской области и поставлено на территории несохранившегося Дмитриевского монастыря.
# Финальное предложение: Мельницы, церковь дома амбары и  бани — всё привезено сюда из разных сёл Владимирской области и поставлено на территории несохранившегося Дмитриевского монастыря
# Исходное предложение: Автор проекта создания музея В.
# После удаления меток: Автор проекта создания музея В.
# Финальное предложение: Автор проекта создания музея в
# Исходное предложение: М.
# После удаления меток: М.
# Финальное предложение: М
# Исходное предложение: Анисимов писал (8) «Забыть свои корни можно и через три поколения.
# После удаления меток: Анисимов писал  «Забыть свои корни можно и через три поколения.
# Финальное предложение: Анисимов писал: Забыть свои корни можно и через три поколения
# Исходное предложение: И потому ещё более дорогой нам становится историческая память»
# После удаления меток: И потому ещё более дорогой нам становится историческая память»
# Финальное предложение: И потому ещё более дорогой нам становится историческая память
# Оригинальный текст: Суздальский музей деревянного зодчества (1) настоящий городок (2) построенный без единого гвоздя. Из дерева здесь всё (3) ложки и лавки в избе, и даже крытая лемехом церковная маковка. Мельницы (4) церковь (5) дома́ (6) амбары и бани (7) всё привезено сюда из разных сёл Владимирской области и поставлено на территории несохранившегося Дмитриевского монастыря. Автор проекта создания музея В. М. Анисимов писал (8) «Забыть свои корни можно и через три поколения. И потому ещё более дорогой нам становится историческая память»
# Изменённый текст: Суздальский музей деревянного зодчества Настоящий городок, построенный без единого гвоздя. Из дерева здесь всё: ложки, и лавки в избе, и даже крытая лемехом церковная маковка. Мельницы, церковь дома амбары и  бани — всё привезено сюда из разных сёл Владимирской области и поставлено на территории несохранившегося Дмитриевского монастыря. Автор проекта создания музея в. М. Анисимов писал: Забыть свои корни можно и через три поколения. И потому ещё более дорогой нам становится историческая память.
# Слова в оригинальном тексте: ['Суздальский', 'музей', 'деревянного', 'зодчества', '(1)', 'настоящий', 'городок', '(2)', 'построенный', 'без', 'единого', 'гвоздя.', 'Из', 'дерева', 'здесь', 'всё', '(3)', 'ложки', 'и', 'лавки', 'в', 'избе,', 'и', 'даже', 'крытая', 'лемехом', 'церковная', 'маковка.', 'Мельницы', '(4)', 'церковь', '(5)', 'дома́', '(6)', 'амбары', 'и', 'бани', '(7)', 'всё', 'привезено', 'сюда', 'из', 'разных', 'сёл', 'Владимирской', 'области', 'и', 'поставлено', 'на', 'территории', 'несохранившегося', 'Дмитриевского', 'монастыря.', 'Автор', 'проекта', 'создания', 'музея', 'В.', 'М.', 'Анисимов', 'писал', '(8)', '«Забыть', 'свои', 'корни', 'можно', 'и', 'через', 'три', 'поколения.', 'И', 'потому', 'ещё', 'более', 'дорогой', 'нам', 'становится', 'историческая', 'память»']
#
# Обрабатываем слово: Суздальский (Индекс 0)
#
# Обрабатываем слово: музей (Индекс 1)
#
# Обрабатываем слово: деревянного (Индекс 2)
#
# Обрабатываем слово: зодчества (Индекс 3)
#
# Обрабатываем слово: (1) (Индекс 4)
# Найдена метка: (1)
# Слово справа от метки: настоящий
# Индекс правой границы в изменённом тексте: -1
# (1): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: настоящий (Индекс 5)
#
# Обрабатываем слово: городок (Индекс 6)
#
# Обрабатываем слово: (2) (Индекс 7)
# Найдена метка: (2)
# Слово справа от метки: построенный
# Индекс правой границы в изменённом тексте: 59
# Слово слева от метки: городок
# Индекс левой границы в изменённом тексте: 50
# Расстояние между границами: 2
# Текст между границами: ','
# (2): Найден текст со специальными символами: ','
#
# Обрабатываем слово: построенный (Индекс 8)
#
# Обрабатываем слово: без (Индекс 9)
#
# Обрабатываем слово: единого (Индекс 10)
#
# Обрабатываем слово: гвоздя. (Индекс 11)
#
# Обрабатываем слово: Из (Индекс 12)
#
# Обрабатываем слово: дерева (Индекс 13)
#
# Обрабатываем слово: здесь (Индекс 14)
#
# Обрабатываем слово: всё (Индекс 15)
#
# Обрабатываем слово: (3) (Индекс 16)
# Найдена метка: (3)
# Слово справа от метки: ложки
# Индекс правой границы в изменённом тексте: 112
# Слово слева от метки: всё
# Индекс левой границы в изменённом тексте: 107
# Расстояние между границами: 2
# Текст между границами: ':'
# (3): Найден текст со специальными символами: ':'
#
# Обрабатываем слово: ложки (Индекс 17)
#
# Обрабатываем слово: и (Индекс 18)
#
# Обрабатываем слово: лавки (Индекс 19)
#
# Обрабатываем слово: в (Индекс 20)
#
# Обрабатываем слово: избе, (Индекс 21)
#
# Обрабатываем слово: и (Индекс 22)
#
# Обрабатываем слово: даже (Индекс 23)
#
# Обрабатываем слово: крытая (Индекс 24)
#
# Обрабатываем слово: лемехом (Индекс 25)
#
# Обрабатываем слово: церковная (Индекс 26)
#
# Обрабатываем слово: маковка. (Индекс 27)
#
# Обрабатываем слово: Мельницы (Индекс 28)
#
# Обрабатываем слово: (4) (Индекс 29)
# Найдена метка: (4)
# Слово справа от метки: церковь
# Индекс правой границы в изменённом тексте: 186
# Слово слева от метки: Мельницы
# Индекс левой границы в изменённом тексте: 176
# Расстояние между границами: 2
# Текст между границами: ','
# (4): Найден текст со специальными символами: ','
#
# Обрабатываем слово: церковь (Индекс 30)
#
# Обрабатываем слово: (5) (Индекс 31)
# Найдена метка: (5)
# Слово справа от метки: дома́
# Индекс правой границы в изменённом тексте: -1
# (5): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: дома́ (Индекс 32)
#
# Обрабатываем слово: (6) (Индекс 33)
# Найдена метка: (6)
# Слово справа от метки: амбары
# Индекс правой границы в изменённом тексте: 199
# Слово слева от метки: дома́
# Индекс левой границы в изменённом тексте: -1
# (6): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: амбары (Индекс 34)
#
# Обрабатываем слово: и (Индекс 35)
#
# Обрабатываем слово: бани (Индекс 36)
#
# Обрабатываем слово: (7) (Индекс 37)
# Найдена метка: (7)
# Слово справа от метки: всё
# Индекс правой границы в изменённом тексте: 107
# Слово слева от метки: бани
# Индекс левой границы в изменённом тексте: -1
# (7): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: всё (Индекс 38)
#
# Обрабатываем слово: привезено (Индекс 39)
#
# Обрабатываем слово: сюда (Индекс 40)
#
# Обрабатываем слово: из (Индекс 41)
#
# Обрабатываем слово: разных (Индекс 42)
#
# Обрабатываем слово: сёл (Индекс 43)
#
# Обрабатываем слово: Владимирской (Индекс 44)
#
# Обрабатываем слово: области (Индекс 45)
#
# Обрабатываем слово: и (Индекс 46)
#
# Обрабатываем слово: поставлено (Индекс 47)
#
# Обрабатываем слово: на (Индекс 48)
#
# Обрабатываем слово: территории (Индекс 49)
#
# Обрабатываем слово: несохранившегося (Индекс 50)
#
# Обрабатываем слово: Дмитриевского (Индекс 51)
#
# Обрабатываем слово: монастыря. (Индекс 52)
#
# Обрабатываем слово: Автор (Индекс 53)
#
# Обрабатываем слово: проекта (Индекс 54)
#
# Обрабатываем слово: создания (Индекс 55)
#
# Обрабатываем слово: музея (Индекс 56)
#
# Обрабатываем слово: В. (Индекс 57)
#
# Обрабатываем слово: М. (Индекс 58)
#
# Обрабатываем слово: Анисимов (Индекс 59)
#
# Обрабатываем слово: писал (Индекс 60)
#
# Обрабатываем слово: (8) (Индекс 61)
# Найдена метка: (8)
# Слово справа от метки: «Забыть
# Индекс правой границы в изменённом тексте: -1
# (8): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: «Забыть (Индекс 62)
#
# Обрабатываем слово: свои (Индекс 63)
#
# Обрабатываем слово: корни (Индекс 64)
#
# Обрабатываем слово: можно (Индекс 65)
#
# Обрабатываем слово: и (Индекс 66)
#
# Обрабатываем слово: через (Индекс 67)
#
# Обрабатываем слово: три (Индекс 68)
#
# Обрабатываем слово: поколения. (Индекс 69)
#
# Обрабатываем слово: И (Индекс 70)
#
# Обрабатываем слово: потому (Индекс 71)
#
# Обрабатываем слово: ещё (Индекс 72)
#
# Обрабатываем слово: более (Индекс 73)
#
# Обрабатываем слово: дорогой (Индекс 74)
#
# Обрабатываем слово: нам (Индекс 75)
#
# Обрабатываем слово: становится (Индекс 76)
#
# Обрабатываем слово: историческая (Индекс 77)
#
# Обрабатываем слово: память» (Индекс 78)
#
# Изменения: {'(1)': 'Nan', '(2)': ',', '(3)': ':', '(4)': ',', '(5)': 'Nan', '(6)': 'Nan', '(7)': 'Nan', '(8)': 'Nan'}
# Исходное предложение: Кремль (1) самая древняя часть столицы России (2) расположенная на берегу Москвы-реки.
# После удаления меток: Кремль  самая древняя часть столицы России  расположенная на берегу Москвы-реки.
# Финальное предложение: кремль — самая древняя часть столицы россии, расположенная на берегу москвыреки
# Исходное предложение: Именно здесь (3) на Боровицком холме (4) ещё в середине XII века князь Юрий Долгорукий основал свою усадьбу-крепость (5) впервые упомянутую в 1147 году.
# После удаления меток: Именно здесь  на Боровицком холме  ещё в середине XII века князь Юрий Долгорукий основал свою усадьбу-крепость  впервые упомянутую в 1147 году.
# Финальное предложение: Именно здесь, на Боровицком холме, ещё в середине XII века князь Юрий долгорукий основал свою усадьбукрепость, впервые упомянутую в 1147 году
# Исходное предложение: Примечательно (6) что стены и башни Кремля были воздвигнуты из красного кирпича (7) на месте прежних белокаменных в конце XV века (8) а колокольня Ивана Великого (9) самое высокое здание на Руси тех времён.
# После удаления меток: Примечательно  что стены и башни Кремля были воздвигнуты из красного кирпича  на месте прежних белокаменных в конце XV века  а колокольня Ивана Великого  самое высокое здание на Руси тех времён.
# Финальное предложение: Примечательно, что стены и башни Кремля были воздвигнуты из красного кирпича на месте прежних белокаменных, в конце XV века, а колокольня Ивана  Великого — самое высокое здание на Руси тех времён
# Оригинальный текст: Кремль (1) самая древняя часть столицы России (2) расположенная на берегу Москвы-реки. Именно здесь (3) на Боровицком холме (4) ещё в середине XII века князь Юрий Долгорукий основал свою усадьбу-крепость (5) впервые упомянутую в 1147 году. Примечательно (6) что стены и башни Кремля были воздвигнуты из красного кирпича (7) на месте прежних белокаменных в конце XV века (8) а колокольня Ивана Великого (9) самое высокое здание на Руси тех времён.
# Изменённый текст: кремль — самая древняя часть столицы россии, расположенная на берегу москвыреки. Именно здесь, на Боровицком холме, ещё в середине XII века князь Юрий долгорукий основал свою усадьбукрепость, впервые упомянутую в 1147 году. Примечательно, что стены и башни Кремля были воздвигнуты из красного кирпича на месте прежних белокаменных, в конце XV века, а колокольня Ивана  Великого — самое высокое здание на Руси тех времён.
# Слова в оригинальном тексте: ['Кремль', '(1)', 'самая', 'древняя', 'часть', 'столицы', 'России', '(2)', 'расположенная', 'на', 'берегу', 'Москвы-реки.', 'Именно', 'здесь', '(3)', 'на', 'Боровицком', 'холме', '(4)', 'ещё', 'в', 'середине', 'XII', 'века', 'князь', 'Юрий', 'Долгорукий', 'основал', 'свою', 'усадьбу-крепость', '(5)', 'впервые', 'упомянутую', 'в', '1147', 'году.', 'Примечательно', '(6)', 'что', 'стены', 'и', 'башни', 'Кремля', 'были', 'воздвигнуты', 'из', 'красного', 'кирпича', '(7)', 'на', 'месте', 'прежних', 'белокаменных', 'в', 'конце', 'XV', 'века', '(8)', 'а', 'колокольня', 'Ивана', 'Великого', '(9)', 'самое', 'высокое', 'здание', 'на', 'Руси', 'тех', 'времён.']
#
# Обрабатываем слово: Кремль (Индекс 0)
#
# Обрабатываем слово: (1) (Индекс 1)
# Найдена метка: (1)
# Слово справа от метки: самая
# Индекс правой границы в изменённом тексте: 9
# Слово слева от метки: Кремль
# Индекс левой границы в изменённом тексте: -1
# (1): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: самая (Индекс 2)
#
# Обрабатываем слово: древняя (Индекс 3)
#
# Обрабатываем слово: часть (Индекс 4)
#
# Обрабатываем слово: столицы (Индекс 5)
#
# Обрабатываем слово: России (Индекс 6)
#
# Обрабатываем слово: (2) (Индекс 7)
# Найдена метка: (2)
# Слово справа от метки: расположенная
# Индекс правой границы в изменённом тексте: 45
# Слово слева от метки: России
# Индекс левой границы в изменённом тексте: -1
# (2): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: расположенная (Индекс 8)
#
# Обрабатываем слово: на (Индекс 9)
#
# Обрабатываем слово: берегу (Индекс 10)
#
# Обрабатываем слово: Москвы-реки. (Индекс 11)
#
# Обрабатываем слово: Именно (Индекс 12)
#
# Обрабатываем слово: здесь (Индекс 13)
#
# Обрабатываем слово: (3) (Индекс 14)
# Найдена метка: (3)
# Слово справа от метки: на
# Индекс правой границы в изменённом тексте: 55
# Слово слева от метки: здесь
# Индекс левой границы в изменённом тексте: -1
# (3): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: на (Индекс 15)
#
# Обрабатываем слово: Боровицком (Индекс 16)
#
# Обрабатываем слово: холме (Индекс 17)
#
# Обрабатываем слово: (4) (Индекс 18)
# Найдена метка: (4)
# Слово справа от метки: ещё
# Индекс правой границы в изменённом тексте: 116
# Слово слева от метки: холме
# Индекс левой границы в изменённом тексте: 109
# Расстояние между границами: 2
# Текст между границами: ','
# (4): Найден текст со специальными символами: ','
#
# Обрабатываем слово: ещё (Индекс 19)
#
# Обрабатываем слово: в (Индекс 20)
#
# Обрабатываем слово: середине (Индекс 21)
#
# Обрабатываем слово: XII (Индекс 22)
#
# Обрабатываем слово: века (Индекс 23)
#
# Обрабатываем слово: князь (Индекс 24)
#
# Обрабатываем слово: Юрий (Индекс 25)
#
# Обрабатываем слово: Долгорукий (Индекс 26)
#
# Обрабатываем слово: основал (Индекс 27)
#
# Обрабатываем слово: свою (Индекс 28)
#
# Обрабатываем слово: усадьбу-крепость (Индекс 29)
#
# Обрабатываем слово: (5) (Индекс 30)
# Найдена метка: (5)
# Слово справа от метки: впервые
# Индекс правой границы в изменённом тексте: 192
# Слово слева от метки: усадьбу-крепость
# Индекс левой границы в изменённом тексте: -1
# (5): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: впервые (Индекс 31)
#
# Обрабатываем слово: упомянутую (Индекс 32)
#
# Обрабатываем слово: в (Индекс 33)
#
# Обрабатываем слово: 1147 (Индекс 34)
#
# Обрабатываем слово: году. (Индекс 35)
#
# Обрабатываем слово: Примечательно (Индекс 36)
#
# Обрабатываем слово: (6) (Индекс 37)
# Найдена метка: (6)
# Слово справа от метки: что
# Индекс правой границы в изменённом тексте: 239
# Слово слева от метки: Примечательно
# Индекс левой границы в изменённом тексте: 224
# Расстояние между границами: 2
# Текст между границами: ','
# (6): Найден текст со специальными символами: ','
#
# Обрабатываем слово: что (Индекс 38)
#
# Обрабатываем слово: стены (Индекс 39)
#
# Обрабатываем слово: и (Индекс 40)
#
# Обрабатываем слово: башни (Индекс 41)
#
# Обрабатываем слово: Кремля (Индекс 42)
#
# Обрабатываем слово: были (Индекс 43)
#
# Обрабатываем слово: воздвигнуты (Индекс 44)
#
# Обрабатываем слово: из (Индекс 45)
#
# Обрабатываем слово: красного (Индекс 46)
#
# Обрабатываем слово: кирпича (Индекс 47)
#
# Обрабатываем слово: (7) (Индекс 48)
# Найдена метка: (7)
# Слово справа от метки: на
# Индекс правой границы в изменённом тексте: 55
# Слово слева от метки: кирпича
# Индекс левой границы в изменённом тексте: -1
# (7): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: на (Индекс 49)
#
# Обрабатываем слово: месте (Индекс 50)
#
# Обрабатываем слово: прежних (Индекс 51)
#
# Обрабатываем слово: белокаменных (Индекс 52)
#
# Обрабатываем слово: в (Индекс 53)
#
# Обрабатываем слово: конце (Индекс 54)
#
# Обрабатываем слово: XV (Индекс 55)
#
# Обрабатываем слово: века (Индекс 56)
#
# Обрабатываем слово: (8) (Индекс 57)
# Найдена метка: (8)
# Слово справа от метки: а
# Индекс правой границы в изменённом тексте: 10
# Слово слева от метки: века
# Индекс левой границы в изменённом тексте: -1
# (8): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: а (Индекс 58)
#
# Обрабатываем слово: колокольня (Индекс 59)
#
# Обрабатываем слово: Ивана (Индекс 60)
#
# Обрабатываем слово: Великого (Индекс 61)
#
# Обрабатываем слово: (9) (Индекс 62)
# Найдена метка: (9)
# Слово справа от метки: самое
# Индекс правой границы в изменённом тексте: 380
# Слово слева от метки: Великого
# Индекс левой границы в изменённом тексте: 369
# Расстояние между границами: 3
# Текст между границами: '—'
# (9): Найден текст со специальными символами: '—'
#
# Обрабатываем слово: самое (Индекс 63)
#
# Обрабатываем слово: высокое (Индекс 64)
#
# Обрабатываем слово: здание (Индекс 65)
#
# Обрабатываем слово: на (Индекс 66)
#
# Обрабатываем слово: Руси (Индекс 67)
#
# Обрабатываем слово: тех (Индекс 68)
#
# Обрабатываем слово: времён. (Индекс 69)
#
# Изменения: {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4)': ',', '(5)': 'Nan', '(6)': ',', '(7)': 'Nan', '(8)': 'Nan', '(9)': '—'}
# Исходное предложение: Дерево (1) материал недолговечный (2) а время и пожары сделали своё дело.
# После удаления меток: Дерево  материал недолговечный  а время и пожары сделали своё дело.
# Финальное предложение: дерево — материал недолговечный, а время и пожары сделали своё дело
# Исходное предложение: Именно из-за них (3) до наших дней не дошли многие выдающиеся сооружения (4) о которых мы знаем только из летописей.
# После удаления меток: Именно из-за них  до наших дней не дошли многие выдающиеся сооружения  о которых мы знаем только из летописей.
# Финальное предложение: Именно изза них до наших дней не дошли многие выдающиеся сооружения, о которых мы знаем только из летописей
# Исходное предложение: При этом центральные районы России (5) почти не сохранили памятники деревянного зодчества.
# После удаления меток: При этом центральные районы России  почти не сохранили памятники деревянного зодчества.
# Финальное предложение: При этом центральные районы России почти не сохранили памятники деревянного зодчества
# Исходное предложение: И только некоторые области Поволжья (6) Урала (7) Сибири и Севера (8) донесли до нас образцы этого высокого искусства.
# После удаления меток: И только некоторые области Поволжья  Урала  Сибири и Севера  донесли до нас образцы этого высокого искусства.
# Финальное предложение: И только некоторые области поволжья урала, Сибири и Севера донесли до нас образцы этого высокого искусства
# Оригинальный текст: Дерево (1) материал недолговечный (2) а время и пожары сделали своё дело. Именно из-за них (3) до наших дней не дошли многие выдающиеся сооружения (4) о которых мы знаем только из летописей. При этом центральные районы России (5) почти не сохранили памятники деревянного зодчества. И только некоторые области Поволжья (6) Урала (7) Сибири и Севера (8) донесли до нас образцы этого высокого искусства.
# Изменённый текст: дерево — материал недолговечный, а время и пожары сделали своё дело. Именно изза них до наших дней не дошли многие выдающиеся сооружения, о которых мы знаем только из летописей. При этом центральные районы России почти не сохранили памятники деревянного зодчества. И только некоторые области поволжья урала, Сибири и Севера донесли до нас образцы этого высокого искусства.
# Слова в оригинальном тексте: ['Дерево', '(1)', 'материал', 'недолговечный', '(2)', 'а', 'время', 'и', 'пожары', 'сделали', 'своё', 'дело.', 'Именно', 'из-за', 'них', '(3)', 'до', 'наших', 'дней', 'не', 'дошли', 'многие', 'выдающиеся', 'сооружения', '(4)', 'о', 'которых', 'мы', 'знаем', 'только', 'из', 'летописей.', 'При', 'этом', 'центральные', 'районы', 'России', '(5)', 'почти', 'не', 'сохранили', 'памятники', 'деревянного', 'зодчества.', 'И', 'только', 'некоторые', 'области', 'Поволжья', '(6)', 'Урала', '(7)', 'Сибири', 'и', 'Севера', '(8)', 'донесли', 'до', 'нас', 'образцы', 'этого', 'высокого', 'искусства.']
#
# Обрабатываем слово: Дерево (Индекс 0)
#
# Обрабатываем слово: (1) (Индекс 1)
# Найдена метка: (1)
# Слово справа от метки: материал
# Индекс правой границы в изменённом тексте: 9
# Слово слева от метки: Дерево
# Индекс левой границы в изменённом тексте: -1
# (1): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: материал (Индекс 2)
#
# Обрабатываем слово: недолговечный (Индекс 3)
#
# Обрабатываем слово: (2) (Индекс 4)
# Найдена метка: (2)
# Слово справа от метки: а
# Индекс правой границы в изменённом тексте: 10
# Слово слева от метки: недолговечный
# Индекс левой границы в изменённом тексте: -1
# (2): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: а (Индекс 5)
#
# Обрабатываем слово: время (Индекс 6)
#
# Обрабатываем слово: и (Индекс 7)
#
# Обрабатываем слово: пожары (Индекс 8)
#
# Обрабатываем слово: сделали (Индекс 9)
#
# Обрабатываем слово: своё (Индекс 10)
#
# Обрабатываем слово: дело. (Индекс 11)
#
# Обрабатываем слово: Именно (Индекс 12)
#
# Обрабатываем слово: из-за (Индекс 13)
#
# Обрабатываем слово: них (Индекс 14)
#
# Обрабатываем слово: (3) (Индекс 15)
# Найдена метка: (3)
# Слово справа от метки: до
# Индекс правой границы в изменённом тексте: 20
# Слово слева от метки: них
# Индекс левой границы в изменённом тексте: -1
# (3): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: до (Индекс 16)
#
# Обрабатываем слово: наших (Индекс 17)
#
# Обрабатываем слово: дней (Индекс 18)
#
# Обрабатываем слово: не (Индекс 19)
#
# Обрабатываем слово: дошли (Индекс 20)
#
# Обрабатываем слово: многие (Индекс 21)
#
# Обрабатываем слово: выдающиеся (Индекс 22)
#
# Обрабатываем слово: сооружения (Индекс 23)
#
# Обрабатываем слово: (4) (Индекс 24)
# Найдена метка: (4)
# Слово справа от метки: о
# Индекс правой границы в изменённом тексте: 5
# Слово слева от метки: сооружения
# Индекс левой границы в изменённом тексте: -1
# (4): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: о (Индекс 25)
#
# Обрабатываем слово: которых (Индекс 26)
#
# Обрабатываем слово: мы (Индекс 27)
#
# Обрабатываем слово: знаем (Индекс 28)
#
# Обрабатываем слово: только (Индекс 29)
#
# Обрабатываем слово: из (Индекс 30)
#
# Обрабатываем слово: летописей. (Индекс 31)
#
# Обрабатываем слово: При (Индекс 32)
#
# Обрабатываем слово: этом (Индекс 33)
#
# Обрабатываем слово: центральные (Индекс 34)
#
# Обрабатываем слово: районы (Индекс 35)
#
# Обрабатываем слово: России (Индекс 36)
#
# Обрабатываем слово: (5) (Индекс 37)
# Найдена метка: (5)
# Слово справа от метки: почти
# Индекс правой границы в изменённом тексте: 213
# Слово слева от метки: России
# Индекс левой границы в изменённом тексте: 206
# Расстояние между границами: 1
# Текст между границами: ''
# (5): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: почти (Индекс 38)
#
# Обрабатываем слово: не (Индекс 39)
#
# Обрабатываем слово: сохранили (Индекс 40)
#
# Обрабатываем слово: памятники (Индекс 41)
#
# Обрабатываем слово: деревянного (Индекс 42)
#
# Обрабатываем слово: зодчества. (Индекс 43)
#
# Обрабатываем слово: И (Индекс 44)
#
# Обрабатываем слово: только (Индекс 45)
#
# Обрабатываем слово: некоторые (Индекс 46)
#
# Обрабатываем слово: области (Индекс 47)
#
# Обрабатываем слово: Поволжья (Индекс 48)
#
# Обрабатываем слово: (6) (Индекс 49)
# Найдена метка: (6)
# Слово справа от метки: Урала
# Индекс правой границы в изменённом тексте: -1
# (6): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: Урала (Индекс 50)
#
# Обрабатываем слово: (7) (Индекс 51)
# Найдена метка: (7)
# Слово справа от метки: Сибири
# Индекс правой границы в изменённом тексте: 308
# Слово слева от метки: Урала
# Индекс левой границы в изменённом тексте: -1
# (7): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: Сибири (Индекс 52)
#
# Обрабатываем слово: и (Индекс 53)
#
# Обрабатываем слово: Севера (Индекс 54)
#
# Обрабатываем слово: (8) (Индекс 55)
# Найдена метка: (8)
# Слово справа от метки: донесли
# Индекс правой границы в изменённом тексте: 324
# Слово слева от метки: Севера
# Индекс левой границы в изменённом тексте: 317
# Расстояние между границами: 1
# Текст между границами: ''
# (8): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: донесли (Индекс 56)
#
# Обрабатываем слово: до (Индекс 57)
#
# Обрабатываем слово: нас (Индекс 58)
#
# Обрабатываем слово: образцы (Индекс 59)
#
# Обрабатываем слово: этого (Индекс 60)
#
# Обрабатываем слово: высокого (Индекс 61)
#
# Обрабатываем слово: искусства. (Индекс 62)
#
# Изменения: {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4)': 'Nan', '(5)': 'Nan', '(6)': 'Nan', '(7)': 'Nan', '(8)': 'Nan'}
# Исходное предложение: Колокольня Ивана Великого (1) это церковь из белого кирпича (2) расположенная на Соборной площади Московского Кремля.
# После удаления меток: Колокольня Ивана Великого  это церковь из белого кирпича  расположенная на Соборной площади Московского Кремля.
# Финальное предложение: Колокольня ивана  Великого — это церковь из белого кирпича, расположенная на Соборной площади Московского кремля
# Исходное предложение: Время её возведения (3) 1500–1508 годы (4) а проектом её создания (5) занимался известный в то время итальянский архитектор Бон Фрязин (6) спроектировавший столп колокольни (7) а также Успенскую звонницу (8) и Филаретову пристройку.
# После удаления меток: Время её возведения  1500–1508 годы  а проектом её создания  занимался известный в то время итальянский архитектор Бон Фрязин  спроектировавший столп колокольни  а также Успенскую звонницу  и Филаретову пристройку.
# Финальное предложение: Время её  возведения — 15001508 годы, а проектом её создания занимался известный в то время итальянский архитектор Бон фрязин, спроектировавший столп колокольни, а также Успенскую звонницу и Филаретову пристройку
# Оригинальный текст: Колокольня Ивана Великого (1) это церковь из белого кирпича (2) расположенная на Соборной площади Московского Кремля. Время её возведения (3) 1500–1508 годы (4) а проектом её создания (5) занимался известный в то время итальянский архитектор Бон Фрязин (6) спроектировавший столп колокольни (7) а также Успенскую звонницу (8) и Филаретову пристройку.
# Изменённый текст: Колокольня ивана  Великого — это церковь из белого кирпича, расположенная на Соборной площади Московского кремля. Время её  возведения — 15001508 годы, а проектом её создания занимался известный в то время итальянский архитектор Бон фрязин, спроектировавший столп колокольни, а также Успенскую звонницу и Филаретову пристройку.
# Слова в оригинальном тексте: ['Колокольня', 'Ивана', 'Великого', '(1)', 'это', 'церковь', 'из', 'белого', 'кирпича', '(2)', 'расположенная', 'на', 'Соборной', 'площади', 'Московского', 'Кремля.', 'Время', 'её', 'возведения', '(3)', '1500–1508', 'годы', '(4)', 'а', 'проектом', 'её', 'создания', '(5)', 'занимался', 'известный', 'в', 'то', 'время', 'итальянский', 'архитектор', 'Бон', 'Фрязин', '(6)', 'спроектировавший', 'столп', 'колокольни', '(7)', 'а', 'также', 'Успенскую', 'звонницу', '(8)', 'и', 'Филаретову', 'пристройку.']
#
# Обрабатываем слово: Колокольня (Индекс 0)
#
# Обрабатываем слово: Ивана (Индекс 1)
#
# Обрабатываем слово: Великого (Индекс 2)
#
# Обрабатываем слово: (1) (Индекс 3)
# Найдена метка: (1)
# Слово справа от метки: это
# Индекс правой границы в изменённом тексте: 29
# Слово слева от метки: Великого
# Индекс левой границы в изменённом тексте: 18
# Расстояние между границами: 3
# Текст между границами: '—'
# (1): Найден текст со специальными символами: '—'
#
# Обрабатываем слово: это (Индекс 4)
#
# Обрабатываем слово: церковь (Индекс 5)
#
# Обрабатываем слово: из (Индекс 6)
#
# Обрабатываем слово: белого (Индекс 7)
#
# Обрабатываем слово: кирпича (Индекс 8)
#
# Обрабатываем слово: (2) (Индекс 9)
# Найдена метка: (2)
# Слово справа от метки: расположенная
# Индекс правой границы в изменённом тексте: 60
# Слово слева от метки: кирпича
# Индекс левой границы в изменённом тексте: 51
# Расстояние между границами: 2
# Текст между границами: ','
# (2): Найден текст со специальными символами: ','
#
# Обрабатываем слово: расположенная (Индекс 10)
#
# Обрабатываем слово: на (Индекс 11)
#
# Обрабатываем слово: Соборной (Индекс 12)
#
# Обрабатываем слово: площади (Индекс 13)
#
# Обрабатываем слово: Московского (Индекс 14)
#
# Обрабатываем слово: Кремля. (Индекс 15)
#
# Обрабатываем слово: Время (Индекс 16)
#
# Обрабатываем слово: её (Индекс 17)
#
# Обрабатываем слово: возведения (Индекс 18)
#
# Обрабатываем слово: (3) (Индекс 19)
# Найдена метка: (3)
# Слово справа от метки: 1500–1508
# Индекс правой границы в изменённом тексте: -1
# (3): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: 1500–1508 (Индекс 20)
#
# Обрабатываем слово: годы (Индекс 21)
#
# Обрабатываем слово: (4) (Индекс 22)
# Найдена метка: (4)
# Слово справа от метки: а
# Индекс правой границы в изменённом тексте: 13
# Слово слева от метки: годы
# Индекс левой границы в изменённом тексте: -1
# (4): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: а (Индекс 23)
#
# Обрабатываем слово: проектом (Индекс 24)
#
# Обрабатываем слово: её (Индекс 25)
#
# Обрабатываем слово: создания (Индекс 26)
#
# Обрабатываем слово: (5) (Индекс 27)
# Найдена метка: (5)
# Слово справа от метки: занимался
# Индекс правой границы в изменённом тексте: 175
# Слово слева от метки: создания
# Индекс левой границы в изменённом тексте: 166
# Расстояние между границами: 1
# Текст между границами: ''
# (5): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: занимался (Индекс 28)
#
# Обрабатываем слово: известный (Индекс 29)
#
# Обрабатываем слово: в (Индекс 30)
#
# Обрабатываем слово: то (Индекс 31)
#
# Обрабатываем слово: время (Индекс 32)
#
# Обрабатываем слово: итальянский (Индекс 33)
#
# Обрабатываем слово: архитектор (Индекс 34)
#
# Обрабатываем слово: Бон (Индекс 35)
#
# Обрабатываем слово: Фрязин (Индекс 36)
#
# Обрабатываем слово: (6) (Индекс 37)
# Найдена метка: (6)
# Слово справа от метки: спроектировавший
# Индекс правой границы в изменённом тексте: 241
# Слово слева от метки: Фрязин
# Индекс левой границы в изменённом тексте: -1
# (6): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: спроектировавший (Индекс 38)
#
# Обрабатываем слово: столп (Индекс 39)
#
# Обрабатываем слово: колокольни (Индекс 40)
#
# Обрабатываем слово: (7) (Индекс 41)
# Найдена метка: (7)
# Слово справа от метки: а
# Индекс правой границы в изменённом тексте: 13
# Слово слева от метки: колокольни
# Индекс левой границы в изменённом тексте: -1
# (7): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: а (Индекс 42)
#
# Обрабатываем слово: также (Индекс 43)
#
# Обрабатываем слово: Успенскую (Индекс 44)
#
# Обрабатываем слово: звонницу (Индекс 45)
#
# Обрабатываем слово: (8) (Индекс 46)
# Найдена метка: (8)
# Слово справа от метки: и
# Индекс правой границы в изменённом тексте: 11
# Слово слева от метки: звонницу
# Индекс левой границы в изменённом тексте: -1
# (8): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: и (Индекс 47)
#
# Обрабатываем слово: Филаретову (Индекс 48)
#
# Обрабатываем слово: пристройку. (Индекс 49)
#
# Изменения: {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': 'Nan', '(5)': 'Nan', '(6)': 'Nan', '(7)': 'Nan', '(8)': 'Nan'}
# Исходное предложение: Заядлые путешественники (1) ищущие (2) что посмотреть в России самого необычного и даже мистического (3) непременно должны спуститься в Кунгурскую пещеру.
# После удаления меток: Заядлые путешественники  ищущие  что посмотреть в России самого необычного и даже мистического  непременно должны спуститься в Кунгурскую пещеру.
# Финальное предложение: Заядлые путешественники ищущие, что посмотреть в России самого необычного и даже мистического, непременно должны спуститься в Кунгурскую пещеру
# Исходное предложение: Сегодня это место (4) самое известное уральское чудо.
# После удаления меток: Сегодня это место  самое известное уральское чудо.
# Финальное предложение: Сегодня это  место — самое известное уральское чудо
# Исходное предложение: Температура здесь не поднимается выше +8 ºC (5) поэтому (6) отправившиеся на досуге полюбоваться сталактитами и сталагмитами (7) уральцы (8) частенько дрожат здесь от холода (9) если забыли надеть перед спуском тёплую куртку и шапку.
# После удаления меток: Температура здесь не поднимается выше +8 ºC  поэтому  отправившиеся на досуге полюбоваться сталактитами и сталагмитами  уральцы  частенько дрожат здесь от холода  если забыли надеть перед спуском тёплую куртку и шапку.
# Финальное предложение: Температура здесь не поднимается выше 8 ºC, поэтому отправившиеся на досуге полюбоваться сталактитами и сталагмитами уральцы частенько дрожат здесь от холода, если забыли надеть перед спуском тёплую куртку и шапку
# Оригинальный текст: Заядлые путешественники (1) ищущие (2) что посмотреть в России самого необычного и даже мистического (3) непременно должны спуститься в Кунгурскую пещеру. Сегодня это место (4) самое известное уральское чудо. Температура здесь не поднимается выше +8 ºC (5) поэтому (6) отправившиеся на досуге полюбоваться сталактитами и сталагмитами (7) уральцы (8) частенько дрожат здесь от холода (9) если забыли надеть перед спуском тёплую куртку и шапку.
# Изменённый текст: Заядлые путешественники ищущие, что посмотреть в России самого необычного и даже мистического, непременно должны спуститься в Кунгурскую пещеру. Сегодня это  место — самое известное уральское чудо. Температура здесь не поднимается выше 8 ºC, поэтому отправившиеся на досуге полюбоваться сталактитами и сталагмитами уральцы частенько дрожат здесь от холода, если забыли надеть перед спуском тёплую куртку и шапку.
# Слова в оригинальном тексте: ['Заядлые', 'путешественники', '(1)', 'ищущие', '(2)', 'что', 'посмотреть', 'в', 'России', 'самого', 'необычного', 'и', 'даже', 'мистического', '(3)', 'непременно', 'должны', 'спуститься', 'в', 'Кунгурскую', 'пещеру.', 'Сегодня', 'это', 'место', '(4)', 'самое', 'известное', 'уральское', 'чудо.', 'Температура', 'здесь', 'не', 'поднимается', 'выше', '+8', 'ºC', '(5)', 'поэтому', '(6)', 'отправившиеся', 'на', 'досуге', 'полюбоваться', 'сталактитами', 'и', 'сталагмитами', '(7)', 'уральцы', '(8)', 'частенько', 'дрожат', 'здесь', 'от', 'холода', '(9)', 'если', 'забыли', 'надеть', 'перед', 'спуском', 'тёплую', 'куртку', 'и', 'шапку.']
#
# Обрабатываем слово: Заядлые (Индекс 0)
#
# Обрабатываем слово: путешественники (Индекс 1)
#
# Обрабатываем слово: (1) (Индекс 2)
# Найдена метка: (1)
# Слово справа от метки: ищущие
# Индекс правой границы в изменённом тексте: 24
# Слово слева от метки: путешественники
# Индекс левой границы в изменённом тексте: 8
# Расстояние между границами: 1
# Текст между границами: ''
# (1): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: ищущие (Индекс 3)
#
# Обрабатываем слово: (2) (Индекс 4)
# Найдена метка: (2)
# Слово справа от метки: что
# Индекс правой границы в изменённом тексте: 32
# Слово слева от метки: ищущие
# Индекс левой границы в изменённом тексте: 24
# Расстояние между границами: 2
# Текст между границами: ','
# (2): Найден текст со специальными символами: ','
#
# Обрабатываем слово: что (Индекс 5)
#
# Обрабатываем слово: посмотреть (Индекс 6)
#
# Обрабатываем слово: в (Индекс 7)
#
# Обрабатываем слово: России (Индекс 8)
#
# Обрабатываем слово: самого (Индекс 9)
#
# Обрабатываем слово: необычного (Индекс 10)
#
# Обрабатываем слово: и (Индекс 11)
#
# Обрабатываем слово: даже (Индекс 12)
#
# Обрабатываем слово: мистического (Индекс 13)
#
# Обрабатываем слово: (3) (Индекс 14)
# Найдена метка: (3)
# Слово справа от метки: непременно
# Индекс правой границы в изменённом тексте: 95
# Слово слева от метки: мистического
# Индекс левой границы в изменённом тексте: 81
# Расстояние между границами: 2
# Текст между границами: ','
# (3): Найден текст со специальными символами: ','
#
# Обрабатываем слово: непременно (Индекс 15)
#
# Обрабатываем слово: должны (Индекс 16)
#
# Обрабатываем слово: спуститься (Индекс 17)
#
# Обрабатываем слово: в (Индекс 18)
#
# Обрабатываем слово: Кунгурскую (Индекс 19)
#
# Обрабатываем слово: пещеру. (Индекс 20)
#
# Обрабатываем слово: Сегодня (Индекс 21)
#
# Обрабатываем слово: это (Индекс 22)
#
# Обрабатываем слово: место (Индекс 23)
#
# Обрабатываем слово: (4) (Индекс 24)
# Найдена метка: (4)
# Слово справа от метки: самое
# Индекс правой границы в изменённом тексте: 166
# Слово слева от метки: место
# Индекс левой границы в изменённом тексте: 158
# Расстояние между границами: 3
# Текст между границами: '—'
# (4): Найден текст со специальными символами: '—'
#
# Обрабатываем слово: самое (Индекс 25)
#
# Обрабатываем слово: известное (Индекс 26)
#
# Обрабатываем слово: уральское (Индекс 27)
#
# Обрабатываем слово: чудо. (Индекс 28)
#
# Обрабатываем слово: Температура (Индекс 29)
#
# Обрабатываем слово: здесь (Индекс 30)
#
# Обрабатываем слово: не (Индекс 31)
#
# Обрабатываем слово: поднимается (Индекс 32)
#
# Обрабатываем слово: выше (Индекс 33)
#
# Обрабатываем слово: +8 (Индекс 34)
#
# Обрабатываем слово: ºC (Индекс 35)
#
# Обрабатываем слово: (5) (Индекс 36)
# Найдена метка: (5)
# Слово справа от метки: поэтому
# Индекс правой границы в изменённом тексте: 242
# Слово слева от метки: ºC
# Индекс левой границы в изменённом тексте: 238
# Расстояние между границами: 2
# Текст между границами: ','
# (5): Найден текст со специальными символами: ','
#
# Обрабатываем слово: поэтому (Индекс 37)
#
# Обрабатываем слово: (6) (Индекс 38)
# Найдена метка: (6)
# Слово справа от метки: отправившиеся
# Индекс правой границы в изменённом тексте: 250
# Слово слева от метки: поэтому
# Индекс левой границы в изменённом тексте: 242
# Расстояние между границами: 1
# Текст между границами: ''
# (6): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: отправившиеся (Индекс 39)
#
# Обрабатываем слово: на (Индекс 40)
#
# Обрабатываем слово: досуге (Индекс 41)
#
# Обрабатываем слово: полюбоваться (Индекс 42)
#
# Обрабатываем слово: сталактитами (Индекс 43)
#
# Обрабатываем слово: и (Индекс 44)
#
# Обрабатываем слово: сталагмитами (Индекс 45)
#
# Обрабатываем слово: (7) (Индекс 46)
# Найдена метка: (7)
# Слово справа от метки: уральцы
# Индекс правой границы в изменённом тексте: 315
# Слово слева от метки: сталагмитами
# Индекс левой границы в изменённом тексте: 302
# Расстояние между границами: 1
# Текст между границами: ''
# (7): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: уральцы (Индекс 47)
#
# Обрабатываем слово: (8) (Индекс 48)
# Найдена метка: (8)
# Слово справа от метки: частенько
# Индекс правой границы в изменённом тексте: 323
# Слово слева от метки: уральцы
# Индекс левой границы в изменённом тексте: 315
# Расстояние между границами: 1
# Текст между границами: ''
# (8): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: частенько (Индекс 49)
#
# Обрабатываем слово: дрожат (Индекс 50)
#
# Обрабатываем слово: здесь (Индекс 51)
#
# Обрабатываем слово: от (Индекс 52)
#
# Обрабатываем слово: холода (Индекс 53)
#
# Обрабатываем слово: (9) (Индекс 54)
# Найдена метка: (9)
# Слово справа от метки: если
# Индекс правой границы в изменённом тексте: 357
# Слово слева от метки: холода
# Индекс левой границы в изменённом тексте: 349
# Расстояние между границами: 2
# Текст между границами: ','
# (9): Найден текст со специальными символами: ','
#
# Обрабатываем слово: если (Индекс 55)
#
# Обрабатываем слово: забыли (Индекс 56)
#
# Обрабатываем слово: надеть (Индекс 57)
#
# Обрабатываем слово: перед (Индекс 58)
#
# Обрабатываем слово: спуском (Индекс 59)
#
# Обрабатываем слово: тёплую (Индекс 60)
#
# Обрабатываем слово: куртку (Индекс 61)
#
# Обрабатываем слово: и (Индекс 62)
#
# Обрабатываем слово: шапку. (Индекс 63)
#
# Изменения: {'(1)': 'Nan', '(2)': ',', '(3)': ',', '(4)': '—', '(5)': ',', '(6)': 'Nan', '(7)': 'Nan', '(8)': 'Nan', '(9)': ','}
# Исходное предложение: Художественные изделия из берёсты (1) оригинальный вид народного творчества.
# После удаления меток: Художественные изделия из берёсты  оригинальный вид народного творчества.
# Финальное предложение: Художественные изделия из  берёсты — оригинальный вид народного творчества
# Исходное предложение: Берёста привлекала внимание народных умельцев тем (2) что при обработке она сохраняла все свои свойства.
# После удаления меток: Берёста привлекала внимание народных умельцев тем  что при обработке она сохраняла все свои свойства.
# Финальное предложение: Берёста привлекала внимание народных умельцев тем, что при обработке она сохраняла все свои свойства
# Исходное предложение: Берёста (3) как материал для бытовых изделий привлекала народных мастеров с давних пор.
# После удаления меток: Берёста  как материал для бытовых изделий привлекала народных мастеров с давних пор.
# Финальное предложение: Берёста как материал для бытовых изделий привлекала народных мастеров с давних пор
# Исходное предложение: Кузовки (4) короба для муки и мёда (5) лукошки и пастушечьи рожки (6) канаты
#
# для рыболовных снастей и солонки (7) всё это делалось из берёсты.
#
# А в строительстве берёсту использовали (8) в качестве изолятора от сырости.
# После удаления меток: Кузовки  короба для муки и мёда  лукошки и пастушечьи рожки  канаты
#
# для рыболовных снастей и солонки  всё это делалось из берёсты.
#
# А в строительстве берёсту использовали  в качестве изолятора от сырости.
# Финальное предложение: Кузовки, короба для муки и мёда, лукошки и пастушечьи рожки, канаты для рыболовных снастей и  солонки — всё это делалось из берёсты, а в строительстве берёсту использовали в качестве изолятора от сырости
# Исходное предложение: Благодаря водонепроницаемости и антисептическим свойствам берёста (9) предохраняла дерево от гниения.
# После удаления меток: Благодаря водонепроницаемости и антисептическим свойствам берёста  предохраняла дерево от гниения.
# Финальное предложение: Благодаря водонепроницаемости и антисептическим свойствам берёста предохраняла дерево от гниения
# Оригинальный текст: Художественные изделия из берёсты (1) оригинальный вид народного творчества. Берёста привлекала внимание народных умельцев тем (2) что при обработке она сохраняла все свои свойства. Берёста (3) как материал для бытовых изделий привлекала народных мастеров с давних пор. Кузовки (4) короба для муки и мёда (5) лукошки и пастушечьи рожки (6) канаты
#
# для рыболовных снастей и солонки (7) всё это делалось из берёсты.
#
# А в строительстве берёсту использовали (8) в качестве изолятора от сырости. Благодаря водонепроницаемости и антисептическим свойствам берёста (9) предохраняла дерево от гниения.
# Изменённый текст: Художественные изделия из  берёсты — оригинальный вид народного творчества. Берёста привлекала внимание народных умельцев тем, что при обработке она сохраняла все свои свойства. Берёста как материал для бытовых изделий привлекала народных мастеров с давних пор. Кузовки, короба для муки и мёда, лукошки и пастушечьи рожки, канаты для рыболовных снастей и  солонки — всё это делалось из берёсты, а в строительстве берёсту использовали в качестве изолятора от сырости. Благодаря водонепроницаемости и антисептическим свойствам берёста предохраняла дерево от гниения.
# Слова в оригинальном тексте: ['Художественные', 'изделия', 'из', 'берёсты', '(1)', 'оригинальный', 'вид', 'народного', 'творчества.', 'Берёста', 'привлекала', 'внимание', 'народных', 'умельцев', 'тем', '(2)', 'что', 'при', 'обработке', 'она', 'сохраняла', 'все', 'свои', 'свойства.', 'Берёста', '(3)', 'как', 'материал', 'для', 'бытовых', 'изделий', 'привлекала', 'народных', 'мастеров', 'с', 'давних', 'пор.', 'Кузовки', '(4)', 'короба', 'для', 'муки', 'и', 'мёда', '(5)', 'лукошки', 'и', 'пастушечьи', 'рожки', '(6)', 'канаты', 'для', 'рыболовных', 'снастей', 'и', 'солонки', '(7)', 'всё', 'это', 'делалось', 'из', 'берёсты.', 'А', 'в', 'строительстве', 'берёсту', 'использовали', '(8)', 'в', 'качестве', 'изолятора', 'от', 'сырости.', 'Благодаря', 'водонепроницаемости', 'и', 'антисептическим', 'свойствам', 'берёста', '(9)', 'предохраняла', 'дерево', 'от', 'гниения.']
#
# Обрабатываем слово: Художественные (Индекс 0)
#
# Обрабатываем слово: изделия (Индекс 1)
#
# Обрабатываем слово: из (Индекс 2)
#
# Обрабатываем слово: берёсты (Индекс 3)
#
# Обрабатываем слово: (1) (Индекс 4)
# Найдена метка: (1)
# Слово справа от метки: оригинальный
# Индекс правой границы в изменённом тексте: 37
# Слово слева от метки: берёсты
# Индекс левой границы в изменённом тексте: 27
# Расстояние между границами: 3
# Текст между границами: '—'
# (1): Найден текст со специальными символами: '—'
#
# Обрабатываем слово: оригинальный (Индекс 5)
#
# Обрабатываем слово: вид (Индекс 6)
#
# Обрабатываем слово: народного (Индекс 7)
#
# Обрабатываем слово: творчества. (Индекс 8)
#
# Обрабатываем слово: Берёста (Индекс 9)
#
# Обрабатываем слово: привлекала (Индекс 10)
#
# Обрабатываем слово: внимание (Индекс 11)
#
# Обрабатываем слово: народных (Индекс 12)
#
# Обрабатываем слово: умельцев (Индекс 13)
#
# Обрабатываем слово: тем (Индекс 14)
#
# Обрабатываем слово: (2) (Индекс 15)
# Найдена метка: (2)
# Слово справа от метки: что
# Индекс правой границы в изменённом тексте: 127
# Слово слева от метки: тем
# Индекс левой границы в изменённом тексте: 122
# Расстояние между границами: 2
# Текст между границами: ','
# (2): Найден текст со специальными символами: ','
#
# Обрабатываем слово: что (Индекс 16)
#
# Обрабатываем слово: при (Индекс 17)
#
# Обрабатываем слово: обработке (Индекс 18)
#
# Обрабатываем слово: она (Индекс 19)
#
# Обрабатываем слово: сохраняла (Индекс 20)
#
# Обрабатываем слово: все (Индекс 21)
#
# Обрабатываем слово: свои (Индекс 22)
#
# Обрабатываем слово: свойства. (Индекс 23)
#
# Обрабатываем слово: Берёста (Индекс 24)
#
# Обрабатываем слово: (3) (Индекс 25)
# Найдена метка: (3)
# Слово справа от метки: как
# Индекс правой границы в изменённом тексте: 186
# Слово слева от метки: Берёста
# Индекс левой границы в изменённом тексте: 178
# Расстояние между границами: 1
# Текст между границами: ''
# (3): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: как (Индекс 26)
#
# Обрабатываем слово: материал (Индекс 27)
#
# Обрабатываем слово: для (Индекс 28)
#
# Обрабатываем слово: бытовых (Индекс 29)
#
# Обрабатываем слово: изделий (Индекс 30)
#
# Обрабатываем слово: привлекала (Индекс 31)
#
# Обрабатываем слово: народных (Индекс 32)
#
# Обрабатываем слово: мастеров (Индекс 33)
#
# Обрабатываем слово: с (Индекс 34)
#
# Обрабатываем слово: давних (Индекс 35)
#
# Обрабатываем слово: пор. (Индекс 36)
#
# Обрабатываем слово: Кузовки (Индекс 37)
#
# Обрабатываем слово: (4) (Индекс 38)
# Найдена метка: (4)
# Слово справа от метки: короба
# Индекс правой границы в изменённом тексте: 271
# Слово слева от метки: Кузовки
# Индекс левой границы в изменённом тексте: 262
# Расстояние между границами: 2
# Текст между границами: ','
# (4): Найден текст со специальными символами: ','
#
# Обрабатываем слово: короба (Индекс 39)
#
# Обрабатываем слово: для (Индекс 40)
#
# Обрабатываем слово: муки (Индекс 41)
#
# Обрабатываем слово: и (Индекс 42)
#
# Обрабатываем слово: мёда (Индекс 43)
#
# Обрабатываем слово: (5) (Индекс 44)
# Найдена метка: (5)
# Слово справа от метки: лукошки
# Индекс правой границы в изменённом тексте: 295
# Слово слева от метки: мёда
# Индекс левой границы в изменённом тексте: 289
# Расстояние между границами: 2
# Текст между границами: ','
# (5): Найден текст со специальными символами: ','
#
# Обрабатываем слово: лукошки (Индекс 45)
#
# Обрабатываем слово: и (Индекс 46)
#
# Обрабатываем слово: пастушечьи (Индекс 47)
#
# Обрабатываем слово: рожки (Индекс 48)
#
# Обрабатываем слово: (6) (Индекс 49)
# Найдена метка: (6)
# Слово справа от метки: канаты
# Индекс правой границы в изменённом тексте: 323
# Слово слева от метки: рожки
# Индекс левой границы в изменённом тексте: 316
# Расстояние между границами: 2
# Текст между границами: ','
# (6): Найден текст со специальными символами: ','
#
# Обрабатываем слово: канаты (Индекс 50)
#
# Обрабатываем слово: для (Индекс 51)
#
# Обрабатываем слово: рыболовных (Индекс 52)
#
# Обрабатываем слово: снастей (Индекс 53)
#
# Обрабатываем слово: и (Индекс 54)
#
# Обрабатываем слово: солонки (Индекс 55)
#
# Обрабатываем слово: (7) (Индекс 56)
# Найдена метка: (7)
# Слово справа от метки: всё
# Индекс правой границы в изменённом тексте: 366
# Слово слева от метки: солонки
# Индекс левой границы в изменённом тексте: 356
# Расстояние между границами: 3
# Текст между границами: '—'
# (7): Найден текст со специальными символами: '—'
#
# Обрабатываем слово: всё (Индекс 57)
#
# Обрабатываем слово: это (Индекс 58)
#
# Обрабатываем слово: делалось (Индекс 59)
#
# Обрабатываем слово: из (Индекс 60)
#
# Обрабатываем слово: берёсты. (Индекс 61)
#
# Обрабатываем слово: А (Индекс 62)
#
# Обрабатываем слово: в (Индекс 63)
#
# Обрабатываем слово: строительстве (Индекс 64)
#
# Обрабатываем слово: берёсту (Индекс 65)
#
# Обрабатываем слово: использовали (Индекс 66)
#
# Обрабатываем слово: (8) (Индекс 67)
# Найдена метка: (8)
# Слово справа от метки: в
# Индекс правой границы в изменённом тексте: 8
# Слово слева от метки: использовали
# Индекс левой границы в изменённом тексте: -1
# (8): Левое слово не найдено, устанавливаем значение 'Nan'
#
# ...
#
# Обрабатываем слово: что (Индекс 38)
#
# Обрабатываем слово: открытом (Индекс 39)
#
# Обрабатываем слово: на (Индекс 40)
#
# Обрабатываем слово: Театральной (Индекс 41)
#
# Обрабатываем слово: площади (Индекс 42)
#
# Обрабатываем слово: Большом (Индекс 43)
#
# Обрабатываем слово: Каменном (Индекс 44)
#
# Обрабатываем слово: театре. (Индекс 45)
#
# Обрабатываем слово: А (Индекс 46)
#
# Обрабатываем слово: сегодня (Индекс 47)
#
# Обрабатываем слово: он (Индекс 48)
#
# Обрабатываем слово: располагается (Индекс 49)
#
# Обрабатываем слово: в (Индекс 50)
#
# Обрабатываем слово: здании (Индекс 51)
#
# Обрабатываем слово: (6) (Индекс 52)
# Найдена метка: (6)
# Слово справа от метки: построенном
# Индекс правой границы в изменённом тексте: 321
# Слово слева от метки: здании
# Индекс левой границы в изменённом тексте: 313
# Расстояние между границами: 2
# Текст между границами: ','
# (6): Найден текст со специальными символами: ','
#
# Обрабатываем слово: построенном (Индекс 53)
#
# Обрабатываем слово: архитектором (Индекс 54)
#
# Обрабатываем слово: Альберто (Индекс 55)
#
# Обрабатываем слово: Кавосом (Индекс 56)
#
# Обрабатываем слово: в (Индекс 57)
#
# Обрабатываем слово: 1859 (Индекс 58)
#
# Обрабатываем слово: году (Индекс 59)
#
# Обрабатываем слово: на (Индекс 60)
#
# Обрабатываем слово: противоположной (Индекс 61)
#
# Обрабатываем слово: стороне (Индекс 62)
#
# Обрабатываем слово: Театральной (Индекс 63)
#
# Обрабатываем слово: площади. (Индекс 64)
#
# Изменения: {'(1)': '—', '(2)': ',', '(3)': ',', '(4)': 'Nan', '(5)': 'Nan', '(6)': ','}
# Исходное предложение: Среди необозримых полей (1) лесов (2) перелесков на северо-западе Пензенской области раскинулось (3) старинное село Тарханы.
# После удаления меток: Среди необозримых полей  лесов  перелесков на северо-западе Пензенской области раскинулось  старинное село Тарханы.
# Финальное предложение: Среди необозримых полей лесов, перелесков на северозападе Пензенской области раскинулось старинное село тарханы
# Исходное предложение: Здесь (4) в имении Арсеньевых (5) провёл детские и отроческие годы Михаил Юрьевич Лермонтов.
# После удаления меток: Здесь  в имении Арсеньевых  провёл детские и отроческие годы Михаил Юрьевич Лермонтов.
# Финальное предложение: Здесь, в имении арсеньевых, провёл детские и отроческие годы Михаил юрьевич лермонтов
# Исходное предложение: Сейчас в бывших Тарханах (6) именуемых ныне Лермонтово (7) находится Государственный музей-заповедник великого русского поэта (8) и писателя.
# После удаления меток: Сейчас в бывших Тарханах  именуемых ныне Лермонтово  находится Государственный музей-заповедник великого русского поэта  и писателя.
# Финальное предложение: Сейчас в бывших тарханах, именуемых ныне лермонтово, находится Государственный музейзаповедник великого русского поэта и писателя
# Исходное предложение: Это уникальный (9) историко-культурный памятник федерального значения.
# После удаления меток: Это уникальный  историко-культурный памятник федерального значения.
# Финальное предложение: Это уникальный историкокультурный памятник федерального значения
# Оригинальный текст: Среди необозримых полей (1) лесов (2) перелесков на северо-западе Пензенской области раскинулось (3) старинное село Тарханы. Здесь (4) в имении Арсеньевых (5) провёл детские и отроческие годы Михаил Юрьевич Лермонтов. Сейчас в бывших Тарханах (6) именуемых ныне Лермонтово (7) находится Государственный музей-заповедник великого русского поэта (8) и писателя. Это уникальный (9) историко-культурный памятник федерального значения.
# Изменённый текст: Среди необозримых полей лесов, перелесков на северозападе Пензенской области раскинулось старинное село тарханы. Здесь, в имении арсеньевых, провёл детские и отроческие годы Михаил юрьевич лермонтов. Сейчас в бывших тарханах, именуемых ныне лермонтово, находится Государственный музейзаповедник великого русского поэта и писателя. Это уникальный историкокультурный памятник федерального значения.
# Слова в оригинальном тексте: ['Среди', 'необозримых', 'полей', '(1)', 'лесов', '(2)', 'перелесков', 'на', 'северо-западе', 'Пензенской', 'области', 'раскинулось', '(3)', 'старинное', 'село', 'Тарханы.', 'Здесь', '(4)', 'в', 'имении', 'Арсеньевых', '(5)', 'провёл', 'детские', 'и', 'отроческие', 'годы', 'Михаил', 'Юрьевич', 'Лермонтов.', 'Сейчас', 'в', 'бывших', 'Тарханах', '(6)', 'именуемых', 'ныне', 'Лермонтово', '(7)', 'находится', 'Государственный', 'музей-заповедник', 'великого', 'русского', 'поэта', '(8)', 'и', 'писателя.', 'Это', 'уникальный', '(9)', 'историко-культурный', 'памятник', 'федерального', 'значения.']
#
# Обрабатываем слово: Среди (Индекс 0)
#
# Обрабатываем слово: необозримых (Индекс 1)
#
# Обрабатываем слово: полей (Индекс 2)
#
# Обрабатываем слово: (1) (Индекс 3)
# Найдена метка: (1)
# Слово справа от метки: лесов
# Индекс правой границы в изменённом тексте: 24
# Слово слева от метки: полей
# Индекс левой границы в изменённом тексте: 18
# Расстояние между границами: 1
# Текст между границами: ''
# (1): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: лесов (Индекс 4)
#
# Обрабатываем слово: (2) (Индекс 5)
# Найдена метка: (2)
# Слово справа от метки: перелесков
# Индекс правой границы в изменённом тексте: 31
# Слово слева от метки: лесов
# Индекс левой границы в изменённом тексте: 24
# Расстояние между границами: 2
# Текст между границами: ','
# (2): Найден текст со специальными символами: ','
#
# Обрабатываем слово: перелесков (Индекс 6)
#
# Обрабатываем слово: на (Индекс 7)
#
# Обрабатываем слово: северо-западе (Индекс 8)
#
# Обрабатываем слово: Пензенской (Индекс 9)
#
# Обрабатываем слово: области (Индекс 10)
#
# Обрабатываем слово: раскинулось (Индекс 11)
#
# Обрабатываем слово: (3) (Индекс 12)
# Найдена метка: (3)
# Слово справа от метки: старинное
# Индекс правой границы в изменённом тексте: 89
# Слово слева от метки: раскинулось
# Индекс левой границы в изменённом тексте: 77
# Расстояние между границами: 1
# Текст между границами: ''
# (3): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: старинное (Индекс 13)
#
# Обрабатываем слово: село (Индекс 14)
#
# Обрабатываем слово: Тарханы. (Индекс 15)
#
# Обрабатываем слово: Здесь (Индекс 16)
#
# Обрабатываем слово: (4) (Индекс 17)
# Найдена метка: (4)
# Слово справа от метки: в
# Индекс правой границы в изменённом тексте: 28
# Слово слева от метки: Здесь
# Индекс левой границы в изменённом тексте: -1
# (4): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: в (Индекс 18)
#
# Обрабатываем слово: имении (Индекс 19)
#
# Обрабатываем слово: Арсеньевых (Индекс 20)
#
# Обрабатываем слово: (5) (Индекс 21)
# Найдена метка: (5)
# Слово справа от метки: провёл
# Индекс правой границы в изменённом тексте: 141
# Слово слева от метки: Арсеньевых
# Индекс левой границы в изменённом тексте: -1
# (5): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: провёл (Индекс 22)
#
# Обрабатываем слово: детские (Индекс 23)
#
# Обрабатываем слово: и (Индекс 24)
#
# Обрабатываем слово: отроческие (Индекс 25)
#
# Обрабатываем слово: годы (Индекс 26)
#
# Обрабатываем слово: Михаил (Индекс 27)
#
# Обрабатываем слово: Юрьевич (Индекс 28)
#
# Обрабатываем слово: Лермонтов. (Индекс 29)
#
# Обрабатываем слово: Сейчас (Индекс 30)
#
# Обрабатываем слово: в (Индекс 31)
#
# Обрабатываем слово: бывших (Индекс 32)
#
# Обрабатываем слово: Тарханах (Индекс 33)
#
# Обрабатываем слово: (6) (Индекс 34)
# Найдена метка: (6)
# Слово справа от метки: именуемых
# Индекс правой границы в изменённом тексте: 226
# Слово слева от метки: Тарханах
# Индекс левой границы в изменённом тексте: -1
# (6): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: именуемых (Индекс 35)
#
# Обрабатываем слово: ныне (Индекс 36)
#
# Обрабатываем слово: Лермонтово (Индекс 37)
#
# Обрабатываем слово: (7) (Индекс 38)
# Найдена метка: (7)
# Слово справа от метки: находится
# Индекс правой границы в изменённом тексте: 253
# Слово слева от метки: Лермонтово
# Индекс левой границы в изменённом тексте: -1
# (7): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: находится (Индекс 39)
#
# Обрабатываем слово: Государственный (Индекс 40)
#
# Обрабатываем слово: музей-заповедник (Индекс 41)
#
# Обрабатываем слово: великого (Индекс 42)
#
# Обрабатываем слово: русского (Индекс 43)
#
# Обрабатываем слово: поэта (Индекс 44)
#
# Обрабатываем слово: (8) (Индекс 45)
# Найдена метка: (8)
# Слово справа от метки: и
# Индекс правой границы в изменённом тексте: 4
# Слово слева от метки: поэта
# Индекс левой границы в изменённом тексте: -1
# (8): Левое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: и (Индекс 46)
#
# Обрабатываем слово: писателя. (Индекс 47)
#
# Обрабатываем слово: Это (Индекс 48)
#
# Обрабатываем слово: уникальный (Индекс 49)
#
# Обрабатываем слово: (9) (Индекс 50)
# Найдена метка: (9)
# Слово справа от метки: историко-культурный
# Индекс правой границы в изменённом тексте: -1
# (9): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: историко-культурный (Индекс 51)
#
# Обрабатываем слово: памятник (Индекс 52)
#
# Обрабатываем слово: федерального (Индекс 53)
#
# Обрабатываем слово: значения. (Индекс 54)
#
# Изменения: {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)': 'Nan', '(5)': 'Nan', '(6)': 'Nan', '(7)': 'Nan', '(8)': 'Nan', '(9)': 'Nan'}
# Исходное предложение: В 1767 году Екатерина II сообщала в письме к Н.
# После удаления меток: В 1767 году Екатерина II сообщала в письме к Н.
# Финальное предложение: В 1767 году Екатерина II сообщала в письме к н
# Исходное предложение: И.
# После удаления меток: И.
# Финальное предложение: И?
# Исходное предложение: Панину (1) «Мы вчера, ввечеру, сюда приехали и нашли город (2) который всячески может слыть столицею большого царства».
# После удаления меток: Панину  «Мы вчера, ввечеру, сюда приехали и нашли город  который всячески может слыть столицею большого царства».
# Финальное предложение: Панину Мы вчера ввечеру сюда приехали и нашли город, который всячески может слыть столицею Большого царства
# Исходное предложение: Считается (3) что именно после визита государыни (4) Казань начала развиваться семимильными шагами (5) строили церкви (6) заводы (7) учебные заведения (8) общественные учреждения и дома
# После удаления меток: Считается  что именно после визита государыни  Казань начала развиваться семимильными шагами  строили церкви  заводы  учебные заведения  общественные учреждения и дома
# Финальное предложение: Считается, что именно после визита государыни Казань начала развиваться семимильными шагами: строили церкви заводы, учебные заведения, общественные учреждения и дома
# Оригинальный текст: В 1767 году Екатерина II сообщала в письме к Н. И. Панину (1) «Мы вчера, ввечеру, сюда приехали и нашли город (2) который всячески может слыть столицею большого царства». Считается (3) что именно после визита государыни (4) Казань начала развиваться семимильными шагами (5) строили церкви (6) заводы (7) учебные заведения (8) общественные учреждения и дома
# Изменённый текст: В 1767 году Екатерина II сообщала в письме к н. И? Панину Мы вчера ввечеру сюда приехали и нашли город, который всячески может слыть столицею Большого царства. Считается, что именно после визита государыни Казань начала развиваться семимильными шагами: строили церкви заводы, учебные заведения, общественные учреждения и дома.
# Слова в оригинальном тексте: ['В', '1767', 'году', 'Екатерина', 'II', 'сообщала', 'в', 'письме', 'к', 'Н.', 'И.', 'Панину', '(1)', '«Мы', 'вчера,', 'ввечеру,', 'сюда', 'приехали', 'и', 'нашли', 'город', '(2)', 'который', 'всячески', 'может', 'слыть', 'столицею', 'большого', 'царства».', 'Считается', '(3)', 'что', 'именно', 'после', 'визита', 'государыни', '(4)', 'Казань', 'начала', 'развиваться', 'семимильными', 'шагами', '(5)', 'строили', 'церкви', '(6)', 'заводы', '(7)', 'учебные', 'заведения', '(8)', 'общественные', 'учреждения', 'и', 'дома']
#
# Обрабатываем слово: В (Индекс 0)
#
# Обрабатываем слово: 1767 (Индекс 1)
#
# Обрабатываем слово: году (Индекс 2)
#
# Обрабатываем слово: Екатерина (Индекс 3)
#
# Обрабатываем слово: II (Индекс 4)
#
# Обрабатываем слово: сообщала (Индекс 5)
#
# Обрабатываем слово: в (Индекс 6)
#
# Обрабатываем слово: письме (Индекс 7)
#
# Обрабатываем слово: к (Индекс 8)
#
# Обрабатываем слово: Н. (Индекс 9)
#
# Обрабатываем слово: И. (Индекс 10)
#
# Обрабатываем слово: Панину (Индекс 11)
#
# Обрабатываем слово: (1) (Индекс 12)
# Найдена метка: (1)
# Слово справа от метки: «Мы
# Индекс правой границы в изменённом тексте: -1
# (1): Правое слово не найдено, устанавливаем значение 'Nan'
#
# Обрабатываем слово: «Мы (Индекс 13)
#
# Обрабатываем слово: вчера, (Индекс 14)
#
# Обрабатываем слово: ввечеру, (Индекс 15)
#
# Обрабатываем слово: сюда (Индекс 16)
#
# Обрабатываем слово: приехали (Индекс 17)
#
# Обрабатываем слово: и (Индекс 18)
#
# Обрабатываем слово: нашли (Индекс 19)
#
# Обрабатываем слово: город (Индекс 20)
#
# Обрабатываем слово: (2) (Индекс 21)
# Найдена метка: (2)
# Слово справа от метки: который
# Индекс правой границы в изменённом тексте: 104
# Слово слева от метки: город
# Индекс левой границы в изменённом тексте: 97
# Расстояние между границами: 2
# Текст между границами: ','
# (2): Найден текст со специальными символами: ','
#
# Обрабатываем слово: который (Индекс 22)
#
# Обрабатываем слово: всячески (Индекс 23)
#
# Обрабатываем слово: может (Индекс 24)
#
# Обрабатываем слово: слыть (Индекс 25)
#
# Обрабатываем слово: столицею (Индекс 26)
#
# Обрабатываем слово: большого (Индекс 27)
#
# Обрабатываем слово: царства». (Индекс 28)
#
# Обрабатываем слово: Считается (Индекс 29)
#
# Обрабатываем слово: (3) (Индекс 30)
# Найдена метка: (3)
# Слово справа от метки: что
# Индекс правой границы в изменённом тексте: 171
# Слово слева от метки: Считается
# Индекс левой границы в изменённом тексте: 160
# Расстояние между границами: 2
# Текст между границами: ','
# (3): Найден текст со специальными символами: ','
#
# Обрабатываем слово: что (Индекс 31)
#
# Обрабатываем слово: именно (Индекс 32)
#
# Обрабатываем слово: после (Индекс 33)
#
# Обрабатываем слово: визита (Индекс 34)
#
# Обрабатываем слово: государыни (Индекс 35)
#
# Обрабатываем слово: (4) (Индекс 36)
# Найдена метка: (4)
# Слово справа от метки: Казань
# Индекс правой границы в изменённом тексте: 206
# Слово слева от метки: государыни
# Индекс левой границы в изменённом тексте: 195
# Расстояние между границами: 1
# Текст между границами: ''
# (4): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: Казань (Индекс 37)
#
# Обрабатываем слово: начала (Индекс 38)
#
# Обрабатываем слово: развиваться (Индекс 39)
#
# Обрабатываем слово: семимильными (Индекс 40)
#
# Обрабатываем слово: шагами (Индекс 41)
#
# Обрабатываем слово: (5) (Индекс 42)
# Найдена метка: (5)
# Слово справа от метки: строили
# Индекс правой границы в изменённом тексте: 253
# Слово слева от метки: шагами
# Индекс левой границы в изменённом тексте: 245
# Расстояние между границами: 2
# Текст между границами: ':'
# (5): Найден текст со специальными символами: ':'
#
# Обрабатываем слово: строили (Индекс 43)
#
# Обрабатываем слово: церкви (Индекс 44)
#
# Обрабатываем слово: (6) (Индекс 45)
# Найдена метка: (6)
# Слово справа от метки: заводы
# Индекс правой границы в изменённом тексте: 268
# Слово слева от метки: церкви
# Индекс левой границы в изменённом тексте: 261
# Расстояние между границами: 1
# Текст между границами: ''
# (6): Специальные символы не найдены, устанавливаем значение 'Nan'
#
# Обрабатываем слово: заводы (Индекс 46)
#
# Обрабатываем слово: (7) (Индекс 47)
# Найдена метка: (7)
# Слово справа от метки: учебные
# Индекс правой границы в изменённом тексте: 276
# Слово слева от метки: заводы
# Индекс левой границы в изменённом тексте: 268
# Расстояние между границами: 2
# Текст между границами: ','
# (7): Найден текст со специальными символами: ','
#
# Обрабатываем слово: учебные (Индекс 48)
#
# Обрабатываем слово: заведения (Индекс 49)
#
# Обрабатываем слово: (8) (Индекс 50)
# Найдена метка: (8)
# Слово справа от метки: общественные
# Индекс правой границы в изменённом тексте: 295
# Слово слева от метки: заведения
# Индекс левой границы в изменённом тексте: 284
# Расстояние между границами: 2
# Текст между границами: ','
# (8): Найден текст со специальными символами: ','
#
# Обрабатываем слово: общественные (Индекс 51)
#
# Обрабатываем слово: учреждения (Индекс 52)
#
# Обрабатываем слово: и (Индекс 53)
#
# Обрабатываем слово: дома (Индекс 54)
#
# Изменения: {'(1)': 'Nan', '(2)': ',', '(3)': ',', '(4)': 'Nan', '(5)': ':', '(6)': 'Nan', '(7)': ',', '(8)': ','}

# %%
df
# Out:
#                                           description punctuation_sign  \
# 0   Укажите цифры, на месте которых в предложении ...                —
# 1   Укажите цифры, на месте которых в предложении ...                ,
# 2   Укажите цифры, на месте которых в предложении ...                ,
# 3   Укажите цифры, на месте которых в предложении ...                —
# 4   Укажите цифры, на месте которых в предложении ...                ,
# 5   Укажите цифры, на месте которых в предложении ...                —
# 6   Укажите цифры, на месте которых в предложении ...                ,
# 7   Укажите цифры, на месте которых в предложении ...                —
# 8   Укажите цифры, на месте которых в предложении ...                ,
# 9   Укажите цифры, на месте которых в предложении ...                —
# 10  Укажите цифры, на месте которых в предложении ...                :
# 11  Укажите цифры, на месте которых в предложении ...                —
# 12  Укажите цифры, на месте которых в предложении ...                ,
# 13  Укажите цифры, на месте которых в предложении ...                —
# 14  Укажите цифры, на месте которых в предложении ...                ,
# 15  Укажите цифры, на месте которых в предложении ...                —
# 16  Укажите цифры, на месте которых в предложении ...                ,
# 17  Укажите цифры, на месте которых в предложении ...                —
# 18  Укажите цифры, на месте которых в предложении ...                ,
# 19  Укажите цифры, на месте которых в предложении ...                ,
# 20  Укажите цифры, на месте которых в предложении ...                ,
# 21  Укажите цифры, на месте которых в предложении ...                ,
# 22  Укажите цифры, на месте которых в предложении ...                :
# 23  Укажите цифры, на месте которых в предложении ...                ,
# 24  Укажите цифры, на месте которых в предложении ...                ,
# 25  Укажите цифры, на месте которых в предложении ...                ,
# 26  Укажите цифры, на месте которых в предложении ...                ,
# 27  Укажите цифры, на месте которых в предложении ...                :
# 28  Укажите цифры, на месте которых в предложении ...                ,
# 29  Укажите цифры, на месте которых в предложении ...                —
# 30  Укажите цифры, на месте которых в предложении ...                ,
# 31  Укажите цифры, на месте которых в предложении ...                ,
# 32  Укажите цифры, на месте которых в предложении ...                ,
# 33  Укажите цифры, на месте которых в предложении ...                —
# 34  Укажите цифры, на месте которых в предложении ...                ,
# 35  Укажите цифры, на месте которых в предложении ...                ,
# 36  Укажите цифры, на месте которых в предложении ...                ,
# 37  Укажите цифры, на месте которых в предложении ...                ,
# 38  Укажите цифры, на месте которых в предложении ...                ,
# 39  Укажите цифры, на месте которых в предложении ...                ,
# 40  Укажите цифры, на месте которых в предложении ...                ,
# 41  Укажите цифры, на месте которых в предложении ...                :
#
#                                             task_text student_answer   answer  \
# 0   Суздальский музей деревянного зодчества (1) на...        1235678       17
# 1   Кремль (1) самая древняя часть столицы России ...         234568   234568
# 2   Дерево (1) материал недолговечный (2) а время ...           2467     2467
# 3   Колокольня Ивана Великого (1) это церковь из б...             17       13
# 4   Заядлые путешественники (1) ищущие (2) что пос...            129    12359
# 5   Художественные изделия из берёсты (1) оригинал...             56       17
# 6   Госудáрственная Третьякóвская галерéя (1) моск...             67    23489
# 7   Национальный театр драмы имени известного алта...          12345       16
# 8   Дом-музей Петра I в Вологде (1) именуемый «Пет...            123   123568
# 9   Домик Петра I (1) единственная постройка (2) с...             17       17
# 10  Арбат уже давно стал главной туристической арт...            347       28
# 11  Расположенный в живописных лесах сибирской тай...             18      236
# 12  Красивая природа (1) обилие бурных рек (2) и ж...             45     1356
# 13  Тобольский государственный историко-архитектур...              1       17
# 14  Петродворец располагается в 30 км от Петербург...           2367     3458
# 15  Семикаракорский фаянс (1) это посуда (2) изгот...             17       17
# 16  Город Кировск (1) расположенный в центре горно...            345  1234569
# 17  Митрополичьи палаты в Ярославле (1) памятник а...            678       19
# 18  Совершая прогулку (1) по улице Баумана в Казан...           3678      237
# 19  В годы Великой Отечественной войны (1) сотрудн...              1    34568
# 20  Знаменитая 60-метровая «падающая» колокольня в...              2     2568
# 21  Только вечером в весеннем лесу начинаешь поним...            567  1234567
# 22  Горы Шиханы (1) уникальный и неповторимый прир...             27       27
# 23  В ситуации (1) когда мёрзнущего под дождём чет...       12345678  1234569
# 24  Водопад Серебряные струи (1) спрятавшийся сред...         345678   125789
# 25  Уникальность Соловецкого архипелага (1) распол...      123456789  1346789
# 26  Вантовые мосты во Владивостоке (1) соединившие...          12345    12469
# 27  Константин Мельников (1) классик русского архи...              7       27
# 28  Русский музей (1) это крупнейший в мире музей ...            246      246
# 29  Центральный сибирский ботанический сад (1) оди...            134       15
# 30  Осень делала дали нежно-голубыми и глубокими (...            357   134567
# 31  Церковь Покрова на Нерли (1) это шедевр архите...          26789    26789
# 32  Из всего списка российских и мировых достоприм...          12457    12457
# 33  Говорят (1) что архитектура (2) душа народа (3...             18       28
# 34  Село Большое Болдино (1) притягивает к себе вс...             56   246789
# 35  Сегодня (1) в Наклонной башне города Невьянска...              7      236
# 36  Ясная Поляна (1) чудесное место. Оказавшись в ...            345   245679
# 37  XVIII век является временем (1) когда Россия «...             18     1247
# 38  Почти с любой точки Красноярска (1) видна стар...          23458    23458
# 39  Мариинский театр (1) один из ведущих музыкальн...            368      236
# 40  Среди необозримых полей (1) лесов (2) перелеск...         123456   124567
# 41  В 1767 году Екатерина II сообщала в письме к Н...            178       15
#
#                                          model_answer  \
# 0   Суздальский музей деревянного зодчества Настоя...
# 1   кремль — самая древняя часть столицы россии, р...
# 2   дерево — материал недолговечный, а время и пож...
# 3   Колокольня ивана  Великого — это церковь из бе...
# 4   Заядлые путешественники ищущие, что посмотреть...
# 5   Художественные изделия из  берёсты — оригиналь...
# 6   Госудáрственная третьякóвская  галерéя — Моско...
# 7   Национальный театр драмы имени известного алта...
# 8   Доммузей петра I в вологде, именуемый Петровск...
# 9   Домик петра i единственная постройка, сохранив...
# 10  Арбат уже давно стал главной туристической арт...
# 11  Расположенный в живописных лесах сибирской тай...
# 12  Красивая природа, обилие бурных рек и живописн...
# 13  Тобольский государственный историкоархитектурн...
# 14  Петродворец располагается в 30 км от Петербург...
# 15  Семикаракорский  фаянс — это посуда, изготовле...
# 16  Город кировск, расположенный в центре горного ...
# 17  Митрополичьи палаты в  Ярославле — памятник ар...
# 18  Совершая прогулку по улице Баумана в казани, т...
# 19  В годы Великой отечественной войны сотрудники ...
# 20  Знаменитая 60метровая падающая колокольня в го...
# 21  Только вечером в весеннем лесу начинаешь поним...
# 22  Горы  Шиханы — уникальный и неповторимый приро...
# 23  В ситуации, когда мёрзнущего под дождём четвер...
# 24  Водопад серебряные струи, спрятавшийся среди з...
# 25  Уникальность соловецкого архипелага, расположе...
# 26  Вантовые мосты во владивостоке, соединившие ко...
# 27  Константин  Мельников — классик русского архит...
# 28  Русский  музей — это крупнейший в мире музей р...
# 29  Центральный сибирский ботанический  сад — один...
# 30  Осень делала дали нежноголубыми и глубокими, а...
# 31  Церковь покрова на  Нерли — это шедевр архитек...
# 32  Из всего списка российских и мировых достоприм...
# 33  Говорят, что  архитектура — душа народа, вопло...
# 34  Село большое болдино притягивает к себе всех, ...
# 35  Сегодня в наклонной башне города Невьянска све...
# 36  Ясная поляна Чудесное место. Оказавшись в этом...
# 37  Xviii век является временем, когда Россия вздо...
# 38  Почти с любой точки Красноярска видна старинна...
# 39  Мариинский  театр — один из ведущих музыкальны...
# 40  Среди необозримых полей лесов, перелесков на с...
# 41  В 1767 году Екатерина II сообщала в письме к н...
#
#                                   punctuation_indices
# 0   {'(1)': 'Nan', '(2)': ',', '(3)': ':', '(4)': ...
# 1   {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 2   {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 3   {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 4   {'(1)': 'Nan', '(2)': ',', '(3)': ',', '(4)': ...
# 5   {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 6   {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 7   {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 8   {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 9   {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 10  {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 11  {'(1)': 'Nan', '(2)': 'Nan', '(3)': '—', '(4)'...
# 12  {'(1)': ',', '(2)': 'Nan', '(3)': ',', '(4)': ...
# 13  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 14  {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 15  {'(1)': '—', '(2)': ',', '(3)': ',', '(4)': ',...
# 16  {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 17  {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 18  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 19  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 20  {'(1)': 'Nan', '(2)': 'Nan', '(3)': '—', '(4)'...
# 21  {'(1)': ',', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 22  {'(1)': '—', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 23  {'(1)': ',', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 24  {'(1)': ',', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 25  {'(1)': ',', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 26  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 27  {'(1)': '—', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 28  {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 29  {'(1)': '—', '(2)': 'Nan', '(3)': ',', '(4)': ...
# 30  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 31  {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 32  {'(1)': ',', '(2)': 'Nan', '(3)': ':', '(4)': ...
# 33  {'(1)': ',', '(2)': '—', '(3)': ',', '(4)': ',...
# 34  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 35  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 36  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 37  {'(1)': ',', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 38  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 39  {'(1)': '—', '(2)': ',', '(3)': ',', '(4)': 'N...
# 40  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 41  {'(1)': 'Nan', '(2)': ',', '(3)': ',', '(4)': ...

# %%
def filter_punctuation_indices(row):
    sign = row['punctuation_sign']
    indices = row['punctuation_indices']

    # Фильтруем индексы по заданному знаку пунктуации
    filtered_indices = [key[1] for key, value in indices.items() if value == sign]

    # Объединяем индексы в строку
    return ''.join(filtered_indices)

# Применяем фильтрацию к каждому ряду датафрейма
df['filtered_punctuation_indices'] = df.apply(filter_punctuation_indices, axis=1)

# Сравнение значений и создание нового столбца 'mark'
df['mark'] = df.apply(lambda row: f"{sum(1 for i in row['filtered_punctuation_indices'] if i in row['student_answer'])}/{len(row['student_answer'])}" if len(row['student_answer']) > 0 else "0/0", axis=1)

df['procent'] = df.apply(
    lambda row: (sum(1 for i in row['filtered_punctuation_indices'] if i in row['answer']) / len(row['answer']) * 100) if len(row['answer']) > 0 else 0, 
    axis=1
)

# Округляем до ближайшего целого числа и преобразуем в целочисленный тип
df['procent'] = df['procent'].round(0).astype(int)

# Формирование JSON выходных данных
assignments = []
for index, row in df.iterrows():
    assignment = {
        "id": index + 1,  # Индексация с 1
        "mark": row['mark'],
        "feedback": row['procent']
    }
    assignments.append(assignment)

output_json = {
    "assignments": assignments
}

# Сохранение в файл JSON
output_file = 'output.json'
with open(output_file, 'w') as json_file:
    json.dump(output_json, json_file, indent=3)

print(f'Данные успешно сохранены в файл {output_file}.')

import numpy as np
df['filtered_punctuation_indices'].replace('', np.nan, inplace=True)
df['filtered_punctuation_indices'] = df['filtered_punctuation_indices'].fillna(0)

df
# Out:
# Данные успешно сохранены в файл output.json.
#                                           description punctuation_sign  \
# 0   Укажите цифры, на месте которых в предложении ...                —
# 1   Укажите цифры, на месте которых в предложении ...                ,
# 2   Укажите цифры, на месте которых в предложении ...                ,
# 3   Укажите цифры, на месте которых в предложении ...                —
# 4   Укажите цифры, на месте которых в предложении ...                ,
# 5   Укажите цифры, на месте которых в предложении ...                —
# 6   Укажите цифры, на месте которых в предложении ...                ,
# 7   Укажите цифры, на месте которых в предложении ...                —
# 8   Укажите цифры, на месте которых в предложении ...                ,
# 9   Укажите цифры, на месте которых в предложении ...                —
# 10  Укажите цифры, на месте которых в предложении ...                :
# 11  Укажите цифры, на месте которых в предложении ...                —
# 12  Укажите цифры, на месте которых в предложении ...                ,
# 13  Укажите цифры, на месте которых в предложении ...                —
# 14  Укажите цифры, на месте которых в предложении ...                ,
# 15  Укажите цифры, на месте которых в предложении ...                —
# 16  Укажите цифры, на месте которых в предложении ...                ,
# 17  Укажите цифры, на месте которых в предложении ...                —
# 18  Укажите цифры, на месте которых в предложении ...                ,
# 19  Укажите цифры, на месте которых в предложении ...                ,
# 20  Укажите цифры, на месте которых в предложении ...                ,
# 21  Укажите цифры, на месте которых в предложении ...                ,
# 22  Укажите цифры, на месте которых в предложении ...                :
# 23  Укажите цифры, на месте которых в предложении ...                ,
# 24  Укажите цифры, на месте которых в предложении ...                ,
# 25  Укажите цифры, на месте которых в предложении ...                ,
# 26  Укажите цифры, на месте которых в предложении ...                ,
# 27  Укажите цифры, на месте которых в предложении ...                :
# 28  Укажите цифры, на месте которых в предложении ...                ,
# 29  Укажите цифры, на месте которых в предложении ...                —
# 30  Укажите цифры, на месте которых в предложении ...                ,
# 31  Укажите цифры, на месте которых в предложении ...                ,
# 32  Укажите цифры, на месте которых в предложении ...                ,
# 33  Укажите цифры, на месте которых в предложении ...                —
# 34  Укажите цифры, на месте которых в предложении ...                ,
# 35  Укажите цифры, на месте которых в предложении ...                ,
# 36  Укажите цифры, на месте которых в предложении ...                ,
# 37  Укажите цифры, на месте которых в предложении ...                ,
# 38  Укажите цифры, на месте которых в предложении ...                ,
# 39  Укажите цифры, на месте которых в предложении ...                ,
# 40  Укажите цифры, на месте которых в предложении ...                ,
# 41  Укажите цифры, на месте которых в предложении ...                :
#
#                                             task_text student_answer   answer  \
# 0   Суздальский музей деревянного зодчества (1) на...        1235678       17
# 1   Кремль (1) самая древняя часть столицы России ...         234568   234568
# 2   Дерево (1) материал недолговечный (2) а время ...           2467     2467
# 3   Колокольня Ивана Великого (1) это церковь из б...             17       13
# 4   Заядлые путешественники (1) ищущие (2) что пос...            129    12359
# 5   Художественные изделия из берёсты (1) оригинал...             56       17
# 6   Госудáрственная Третьякóвская галерéя (1) моск...             67    23489
# 7   Национальный театр драмы имени известного алта...          12345       16
# 8   Дом-музей Петра I в Вологде (1) именуемый «Пет...            123   123568
# 9   Домик Петра I (1) единственная постройка (2) с...             17       17
# 10  Арбат уже давно стал главной туристической арт...            347       28
# 11  Расположенный в живописных лесах сибирской тай...             18      236
# 12  Красивая природа (1) обилие бурных рек (2) и ж...             45     1356
# 13  Тобольский государственный историко-архитектур...              1       17
# 14  Петродворец располагается в 30 км от Петербург...           2367     3458
# 15  Семикаракорский фаянс (1) это посуда (2) изгот...             17       17
# 16  Город Кировск (1) расположенный в центре горно...            345  1234569
# 17  Митрополичьи палаты в Ярославле (1) памятник а...            678       19
# 18  Совершая прогулку (1) по улице Баумана в Казан...           3678      237
# 19  В годы Великой Отечественной войны (1) сотрудн...              1    34568
# 20  Знаменитая 60-метровая «падающая» колокольня в...              2     2568
# 21  Только вечером в весеннем лесу начинаешь поним...            567  1234567
# 22  Горы Шиханы (1) уникальный и неповторимый прир...             27       27
# 23  В ситуации (1) когда мёрзнущего под дождём чет...       12345678  1234569
# 24  Водопад Серебряные струи (1) спрятавшийся сред...         345678   125789
# 25  Уникальность Соловецкого архипелага (1) распол...      123456789  1346789
# 26  Вантовые мосты во Владивостоке (1) соединившие...          12345    12469
# 27  Константин Мельников (1) классик русского архи...              7       27
# 28  Русский музей (1) это крупнейший в мире музей ...            246      246
# 29  Центральный сибирский ботанический сад (1) оди...            134       15
# 30  Осень делала дали нежно-голубыми и глубокими (...            357   134567
# 31  Церковь Покрова на Нерли (1) это шедевр архите...          26789    26789
# 32  Из всего списка российских и мировых достоприм...          12457    12457
# 33  Говорят (1) что архитектура (2) душа народа (3...             18       28
# 34  Село Большое Болдино (1) притягивает к себе вс...             56   246789
# 35  Сегодня (1) в Наклонной башне города Невьянска...              7      236
# 36  Ясная Поляна (1) чудесное место. Оказавшись в ...            345   245679
# 37  XVIII век является временем (1) когда Россия «...             18     1247
# 38  Почти с любой точки Красноярска (1) видна стар...          23458    23458
# 39  Мариинский театр (1) один из ведущих музыкальн...            368      236
# 40  Среди необозримых полей (1) лесов (2) перелеск...         123456   124567
# 41  В 1767 году Екатерина II сообщала в письме к Н...            178       15
#
#                                          model_answer  \
# 0   Суздальский музей деревянного зодчества Настоя...
# 1   кремль — самая древняя часть столицы россии, р...
# 2   дерево — материал недолговечный, а время и пож...
# 3   Колокольня ивана  Великого — это церковь из бе...
# 4   Заядлые путешественники ищущие, что посмотреть...
# 5   Художественные изделия из  берёсты — оригиналь...
# 6   Госудáрственная третьякóвская  галерéя — Моско...
# 7   Национальный театр драмы имени известного алта...
# 8   Доммузей петра I в вологде, именуемый Петровск...
# 9   Домик петра i единственная постройка, сохранив...
# 10  Арбат уже давно стал главной туристической арт...
# 11  Расположенный в живописных лесах сибирской тай...
# 12  Красивая природа, обилие бурных рек и живописн...
# 13  Тобольский государственный историкоархитектурн...
# 14  Петродворец располагается в 30 км от Петербург...
# 15  Семикаракорский  фаянс — это посуда, изготовле...
# 16  Город кировск, расположенный в центре горного ...
# 17  Митрополичьи палаты в  Ярославле — памятник ар...
# 18  Совершая прогулку по улице Баумана в казани, т...
# 19  В годы Великой отечественной войны сотрудники ...
# 20  Знаменитая 60метровая падающая колокольня в го...
# 21  Только вечером в весеннем лесу начинаешь поним...
# 22  Горы  Шиханы — уникальный и неповторимый приро...
# 23  В ситуации, когда мёрзнущего под дождём четвер...
# 24  Водопад серебряные струи, спрятавшийся среди з...
# 25  Уникальность соловецкого архипелага, расположе...
# 26  Вантовые мосты во владивостоке, соединившие ко...
# 27  Константин  Мельников — классик русского архит...
# 28  Русский  музей — это крупнейший в мире музей р...
# 29  Центральный сибирский ботанический  сад — один...
# 30  Осень делала дали нежноголубыми и глубокими, а...
# 31  Церковь покрова на  Нерли — это шедевр архитек...
# 32  Из всего списка российских и мировых достоприм...
# 33  Говорят, что  архитектура — душа народа, вопло...
# 34  Село большое болдино притягивает к себе всех, ...
# 35  Сегодня в наклонной башне города Невьянска све...
# 36  Ясная поляна Чудесное место. Оказавшись в этом...
# 37  Xviii век является временем, когда Россия вздо...
# 38  Почти с любой точки Красноярска видна старинна...
# 39  Мариинский  театр — один из ведущих музыкальны...
# 40  Среди необозримых полей лесов, перелесков на с...
# 41  В 1767 году Екатерина II сообщала в письме к н...
#
#                                   punctuation_indices  \
# 0   {'(1)': 'Nan', '(2)': ',', '(3)': ':', '(4)': ...
# 1   {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 2   {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 3   {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 4   {'(1)': 'Nan', '(2)': ',', '(3)': ',', '(4)': ...
# 5   {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 6   {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 7   {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 8   {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 9   {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 10  {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 11  {'(1)': 'Nan', '(2)': 'Nan', '(3)': '—', '(4)'...
# 12  {'(1)': ',', '(2)': 'Nan', '(3)': ',', '(4)': ...
# 13  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 14  {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 15  {'(1)': '—', '(2)': ',', '(3)': ',', '(4)': ',...
# 16  {'(1)': 'Nan', '(2)': 'Nan', '(3)': 'Nan', '(4...
# 17  {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 18  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 19  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 20  {'(1)': 'Nan', '(2)': 'Nan', '(3)': '—', '(4)'...
# 21  {'(1)': ',', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 22  {'(1)': '—', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 23  {'(1)': ',', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 24  {'(1)': ',', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 25  {'(1)': ',', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 26  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 27  {'(1)': '—', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 28  {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 29  {'(1)': '—', '(2)': 'Nan', '(3)': ',', '(4)': ...
# 30  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 31  {'(1)': '—', '(2)': ',', '(3)': 'Nan', '(4)': ...
# 32  {'(1)': ',', '(2)': 'Nan', '(3)': ':', '(4)': ...
# 33  {'(1)': ',', '(2)': '—', '(3)': ',', '(4)': ',...
# 34  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 35  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 36  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 37  {'(1)': ',', '(2)': 'Nan', '(3)': 'Nan', '(4)'...
# 38  {'(1)': 'Nan', '(2)': 'Nan', '(3)': ',', '(4)'...
# 39  {'(1)': '—', '(2)': ',', '(3)': ',', '(4)': 'N...
# 40  {'(1)': 'Nan', '(2)': ',', '(3)': 'Nan', '(4)'...
# 41  {'(1)': 'Nan', '(2)': ',', '(3)': ',', '(4)': ...
#
#    filtered_punctuation_indices mark  procent
# 0                             0  0/7        0
# 1                            46  2/6       33
# 2                             0  0/4        0
# 3                             1  1/2       50
# 4                          2359  2/3       80
# 5                            17  0/2      100
# 6                           289  0/2       60
# 7                            16  1/5      100
# 8                            68  0/3       33
# 9                             0  0/2        0
# 10                            0  0/3        0
# 11                           36  0/2       67
# 12                          135  1/2       75
# 13                            7  0/1       50
# 14                           48  0/4       50
# 15                            1  1/2       50
# 16                         4569  2/3       57
# 17                            1  0/3       50
# 18                           37  2/4       67
# 19                          356  0/1       60
# 20                           56  0/1       50
# 21                        12467  2/3       71
# 22                            7  1/2       50
# 23                          126  3/8       43
# 24                         1279  1/6       67
# 25                        14678  5/9       71
# 26                          249  2/5       60
# 27                            7  1/1       50
# 28                            2  1/3       33
# 29                           15  1/3      100
# 30                          356  2/3       50
# 31                        26789  5/5      100
# 32                           14  2/5       40
# 33                           28  1/2      100
# 34                            2  0/2       17
# 35                            3  0/1       33
# 36                         2679  0/3       67
# 37                          147  1/2       75
# 38                          345  3/5       60
# 39                          236  2/3      100
# 40                            2  1/6       17
# 41                            5  0/3       50

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Функция для расчета метрик для каждой группы
def calculate_metrics_for_group(group):
    # Убираем строки с пропусками
    group = group.dropna(subset=['answer', 'filtered_punctuation_indices'])
    
    y_true = list(map(int, group['answer']))
    y_pred = list(map(int, group['filtered_punctuation_indices']))


    # Метрики точности, полноты и F1
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    
    return pd.Series({
        'Precision': precision * 100,
        'Recall': recall * 100,
    })

# Группировка по значению punctuation_sign и расчет метрик
metrics_by_group = df.groupby('punctuation_sign').apply(calculate_metrics_for_group)

# Вывод метрик для каждой группы
print(metrics_by_group)
# Out:
#                   Precision     Recall
# punctuation_sign
# ,                 53.191489  50.000000
# :                 50.000000  50.000000
# —                 63.636364  65.454545
